# %% [markdown]
# # keras model

# %% [markdown]
# ## pylibs

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import cv2
import glob
import pprint
import random
import datetime
import numpy as np
import pandas as pd
from tqdm import tqdm
import tensorflow as tf
from keras.models import Model
from scipy.ndimage import zoom
import matplotlib.pyplot as plt
from keras.optimizers import SGD, Adam, Adagrad, Adadelta, Nadam
from tensorflow_addons.optimizers import Yogi
from adabelief_tf import AdaBeliefOptimizer
from keras.regularizers import l2
from keras.models import load_model
from matplotlib import pyplot as plt
from PIL import Image, ImageDraw, ImageFont
from keras import Sequential
from random import randint, choice, shuffle
from keras.callbacks import EarlyStopping
from keras.callbacks import TensorBoard
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint, Callback, LearningRateScheduler
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, SeparableConv2D, Input, Concatenate, GlobalAveragePooling2D, CuDNNLSTM
# Out:
# c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.12.0 and strictly below 2.15.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.10.1 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %% [markdown]
# ## Extra

# %%
def print_Color(Input: str, colors: list, print_END: str = '\n', advanced_mode: bool = False) -> None:
    '''
    Prints colored text to the console using advanced terminal colors.

    Args:
        Input (str): The input string to be printed. In advanced mode, '~*' is used to separate different parts of the string to be printed in different colors.
        colors (list): A list of colors for the text. In non-advanced mode, only the first color in the list is used. In advanced mode, each color corresponds to a part of the input string separated by '~*'.
        print_END (str): The string appended after the final output. Default is '\\n'.
        advanced_mode (bool): If True, enables advanced mode that allows multiple colors in one string. Default is False.

    Examples:
    ~~~python
        print_Color('Hello, World!', ['green']) 
        # Prints 'Hello, World!' in green.

        print_Color('~*Hello in green~*Hello in red', ['green', 'red'], advanced_mode=True) 
        # Prints 'Hello in green' in green and 'Hello in red' in red.

    Note:
        The advanced terminal colors can be used by providing the escape sequences directly in the colors list.
        If an invalid color is provided, an error message will be printed.
    '''
    color_code = {
        'black': '\x1b[0;30m',
        'red': '\x1b[0;31m',
        'green': '\x1b[0;32m',
        'yellow': '\x1b[0;33m',
        'blue': '\x1b[0;34m',
        'magenta': '\x1b[0;35m',
        'cyan': '\x1b[0;36m',
        'white': '\x1b[0;37m',
        'normal': '\x1b[0m',
        'bg_black': '\x1b[40m',
        'bg_red': '\x1b[41m',
        'bg_green': '\x1b[42m',
        'bg_yellow': '\x1b[43m',
        'bg_blue': '\x1b[44m',
        'bg_magenta': '\x1b[45m',
        'bg_cyan': '\x1b[46m',
        'bg_white': '\x1b[47m',
        'bg_normal': '\x1b[49m',
        'light_gray': '\x1b[0;90m',
        'light_red': '\x1b[0;91m',
        'light_green': '\x1b[0;92m',
        'light_yellow': '\x1b[0;93m',
        'light_blue': '\x1b[0;94m',
        'light_magenta': '\x1b[0;95m',
        'light_cyan': '\x1b[0;96m',
        'light_white': '\x1b[0;97m',
        'bg_light_gray': '\x1b[0;100m',
        'bg_light_red': '\x1b[0;101m',
        'bg_light_green': '\x1b[0;102m',
        'bg_light_yellow': '\x1b[0;103m',
        'bg_light_blue': '\x1b[0;104m',
        'bg_light_magenta': '\x1b[0;105m',
        'bg_light_cyan': '\x1b[0;106m',
        'bg_light_white': '\x1b[0;107m',
        'bold': '\x1b[1m',
        'underline': '\x1b[4m',
        'blink': '\x1b[5m'
    }

    if not advanced_mode:
        if colors[0] in color_code:
            print(color_code[colors[0]] + Input + '\x1b[0m', end=print_END)
        else:
            print('[print_Color] ERROR: Invalid color input!!!')
    else:
        substrings = Input.split('~*')
        if len(substrings) != len(colors) + 1:
            print("[print_Color] ERROR: Number of colors and number of '~*' don't match!!!")
        else:
            for sub_str, color in zip(substrings, ['normal'] + colors):
                if color in color_code:
                    print(color_code[color] + sub_str + '\x1b[0m', end='')
                else:
                    print(f"\n[print_Color] ERROR: Invalid color!!! The input color: '{color}' input list index: {colors.index(color)}")
            print('', end=print_END)

# %% [markdown]
# ## Conf

# %% [markdown]
# ### Data processing conf

# %%
# Directory paths
train_dir = 'Data_set/train'
test_dir = 'Data_set/test'
validation_dir = 'Data_set/val'
img_res = [224, 224, 3]
# img_res = [284, 284, 3]
interpolation_order_IFG = 2
categorical_IMP = True
Make_EV_DATA = False
R_fill_mode = True
add_img_grain = True
Save_TS = True
ADBD = 1
OP_HDC = False
SL_EX = '_V1'
LNTS = 0
adjust_brightness_Mode = True

# %% [markdown]
# ### Other

# %%
SAVE_TYPE = 'H5'

# %% [markdown]
# ## data processing with image

# %%
#add_image_grain
def add_image_grain(image, intensity = 0.01):
    # Generate random noise array
    noise = np.random.randint(0, 255, size=image.shape, dtype=np.uint8)

    # Scale the noise array
    scaled_noise = (noise * intensity).astype(np.float32)
    # Add the noise to the image
    noisy_image = cv2.add(image, scaled_noise)

    return noisy_image
#adjust_brightness
# V1
def adjust_brightness(images, target_average):
    # Calculate the average pixel value of all the images
    overall_average = np.mean(images)

    # Iterate over each image in the array
    for i in range(len(images)):
        # Calculate the average pixel value of the current image
        image_average = np.mean(images[i])

        # Compare the image average with the overall average
        if image_average > overall_average + 10:
            # Increase brightness by adding a constant value
            images[i] = np.clip(images[i] - random.randint(6, 25), 0, 255)
        elif image_average < overall_average - 10:
            # Decrease brightness by subtracting a constant value
            images[i] = np.clip(images[i] + random.randint(6, 25), 0, 255)

    return images
# V2 (Very slow NOT Recommended)
# def adjust_brightness(images, target_average):
#     # Calculate the average pixel value of all the images
#     overall_average = np.mean(images)

#     # Initialize a variable to keep track of the number of deleted images
#     deleted_images = 0

#     # Create a progress bar
#     pbar = tqdm(total=len(images), desc='Processing images')

#     # Iterate over each image in the array
#     for i in range(len(images)):
#         # Adjust the index to account for deleted images
#         adjusted_index = i - deleted_images

#         # Calculate the average pixel value of the current image
#         image_average = np.mean(images[adjusted_index])

#         # Compare the image average with the overall average
#         if image_average > overall_average + 50 or image_average < overall_average - 60:
#             # If the image brightness is 45 units higher than the overall average, delete the image
#             images = np.delete(images, adjusted_index, axis=0)
#             # Increment the count of deleted images
#             deleted_images += 1
#         elif image_average > overall_average + 10:
#             # Increase brightness by adding a random value between 6 and 25
#             images[adjusted_index] = np.clip(images[adjusted_index] - random.randint(6, 25), 0, 255)
#         elif image_average < overall_average - 10:
#             # Decrease brightness by subtracting a random value between 6 and 25
#             images[adjusted_index] = np.clip(images[adjusted_index] + random.randint(6, 25), 0, 255)

#         # Update the progress bar
#         pbar.update(1)

#     # Close the progress bar
#     pbar.close()

#     print(f'deleted_images: {deleted_images}')
#     return images
#apply_clahe_rgb_array
def apply_clahe_rgb_array(images, clip_limit=1.8, tile_grid_size=(8, 8)):
    # Create a CLAHE object
    clahe = cv2.createCLAHE(clipLimit=clip_limit, tileGridSize=tile_grid_size)
    
    # Iterate over each image in the array
    for i in range(len(images)):
        # Split the image into color channels
        b, g, r = cv2.split(images[i])
        
        # Convert the channels to the appropriate format
        b = cv2.convertScaleAbs(b)
        g = cv2.convertScaleAbs(g)
        r = cv2.convertScaleAbs(r)
        
        # Apply adaptive histogram equalization to each channel
        equalized_b = clahe.apply(b)
        equalized_g = clahe.apply(g)
        equalized_r = clahe.apply(r)

        # Merge the equalized channels back into an image
        equalized_image = cv2.merge((equalized_b, equalized_g, equalized_r))

        # Replace the original image with the equalized image in the array
        images[i] = equalized_image

    return images
#noise_func
def noise_func(image):
    noise_type = np.random.choice(['L1', 'L2', 'L3', 'none'])
    new_image = np.copy(image)
    
    if noise_type == 'L3':
        intensityL2 = random.uniform(0.001, 0.024)
        intensityL1 = random.uniform(0.005, 0.026)
    else:
        intensityL2 = random.uniform(0.001, 0.037)
        intensityL1 = random.uniform(0.001, 0.037)
    
    block_size_L1 = random.randint(16, 32)
    block_size_L2 = random.randint(32, 64)
    
    if noise_type == 'L2' or noise_type == 'L3':
        for i in range(0, image.shape[0], block_size_L2):
            for j in range(0, image.shape[1], block_size_L2):
                block = image[i:i+block_size_L2, j:j+block_size_L2]
                block = (np.random.rand() * intensityL2 + 1) * block
                new_image[i:i+block_size_L2, j:j+block_size_L2] = block
        image = new_image      
        
    if noise_type == 'L1' or noise_type == 'L3': 
        for i in range(0, image.shape[0], block_size_L1):
            for j in range(0, image.shape[1], block_size_L1):
                block = image[i:i+block_size_L1, j:j+block_size_L1]
                block = (np.random.rand() * intensityL1 + 1) * block
                new_image[i:i+block_size_L1, j:j+block_size_L1] = block
    
    if add_img_grain:
        intensity = random.uniform(0, 0.026)  # Random intensity between 0 and 0.026
        new_image = add_image_grain(new_image, intensity=intensity)
    return new_image
#shuffle_data
def shuffle_data(x, y):
    indices = np.arange(x.shape[0])
    np.random.shuffle(indices)
    x = x[indices]
    y = y[indices]
    return x, y
#save_images_to_dir
def save_images_to_dir(images, labels, dir_path):
    # create the directory if it doesn't exist
    if not os.path.exists(dir_path):
        os.makedirs(dir_path)
    # iterate over the images and labels
    for i, (image, label) in enumerate(zip(images, labels)):
        # get the class label
        class_label = np.argmax(label)
        # create the file path
        file_path = os.path.join(dir_path, f'image_{i}_class_{class_label}.png')
        # save the image to the file path
        plt.imsave(file_path, image.squeeze())
# Create an ImageDataGenerator for the training set
if OP_HDC:
    print_Color('Using OP_HDC IDG...', ['yellow'])
    train_datagen = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True,
        rotation_range=179,
        zoom_range=0.24, 
        shear_range=0.22,
        width_shift_range=0.21,
        brightness_range=(0.86, 1.13),
        height_shift_range=0.21,
        channel_shift_range=100,
        featurewise_center=False,
        featurewise_std_normalization=False,
        interpolation_order=interpolation_order_IFG,
        fill_mode='nearest', # constant
        preprocessing_function=noise_func
    )
else:
    print_Color('Using Def IDG...', ['yellow'])
    train_datagen = ImageDataGenerator(
        horizontal_flip=True,
        vertical_flip=True,
        rotation_range=179,
        zoom_range=0.26, 
        shear_range=0.25,
        width_shift_range=0.25,
        brightness_range=(0.8, 1.2),
        height_shift_range=0.25,
        channel_shift_range=100,
        featurewise_center=False,
        interpolation_order=interpolation_order_IFG,
        featurewise_std_normalization=False,
        fill_mode='nearest', # constant
        preprocessing_function=noise_func
    )
train_datagen_SM = ImageDataGenerator(
    horizontal_flip=False,
    vertical_flip=False,
    rotation_range=20,
    zoom_range=0.07, 
    shear_range=0.07,
    width_shift_range=0.07,
    brightness_range=(0.99, 1.01),
    height_shift_range=0.07,
    channel_shift_range=0,
    featurewise_center=False,
    interpolation_order=interpolation_order_IFG,
    featurewise_std_normalization=False
)
# Create an iterator for the training set
train_generator_SM = train_datagen_SM.flow_from_directory(
    train_dir,
    target_size=(img_res[0], img_res[1]),
    batch_size=sum([len(files) for r, d, files in os.walk(train_dir)]),
    class_mode='binary')
# Create an ImageDataGenerator for the validation set (OP)
if Make_EV_DATA:
    val_datagen = ImageDataGenerator(
        horizontal_flip=False,
        zoom_range = 0.01, 
        width_shift_range=0.01, 
        interpolation_order=interpolation_order_IFG,
        height_shift_range=0.01)

    # Create an iterator for the validation set
    val_generator = val_datagen.flow_from_directory(
        validation_dir,
        target_size=(img_res[0], img_res[1]),
        batch_size=sum([len(files) for r, d, files in os.walk(validation_dir)]),
        class_mode='binary',
        color_mode='rgb')

    # Create an ImageDataGenerator for the test set
    test_datagen = ImageDataGenerator(
        horizontal_flip=False,
        zoom_range = 0.01, 
        width_shift_range=0.01, 
        interpolation_order=interpolation_order_IFG,
        height_shift_range=0.01)

    # Create an iterator for the test set
    test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_res[0], img_res[1]),
        batch_size=sum([len(files) for r, d, files in os.walk(test_dir)]),
        class_mode='binary',
        color_mode='rgb')
# Load all images and labels into memory
print_Color('Loading all images and labels into memory...', ['yellow'])
x_train, y_train = next(iter(train_generator_SM))
if Make_EV_DATA:
    x_val, y_val = next(iter(val_generator))
    x_test, y_test = next(iter(test_generator))
# fit parameters from data
# train_datagen.fit(x_train)
#to_categorical (TEMP)
if categorical_IMP:
    print_Color('Making categorical data...', ['yellow'])
    y_train = to_categorical(y_train, num_classes=2)
    if Make_EV_DATA:
        y_val = to_categorical(y_val, num_classes=2)
        y_test = to_categorical(y_test, num_classes=2)
print_Color(f'~*Generating augmented data ~*[~*ADBD: ~*{str(ADBD)}~*]~*...',
            ['yellow', 'cyan', 'green', 'red', 'cyan', 'yellow'],
            advanced_mode=True)
if ADBD > 0:
    for i in range(ADBD):
        # ADB_clip_limit Scheduler>>>
        if i == 0:
            ADB_clip_limit = 1.6
        else:
            #V1>>>
            CL_SLM = 2.4
            ADB_clip_limit = max(2 / (i + 1)**CL_SLM, 0.05)
            # Try it in win graphing calculator copy and paste:
            #  ┌-------------┬--┬---------------┐
            #  │ 𝑦=2/(𝑥+1)^𝑧 ├OR┤ 𝑦=2/(𝑥+1)^2.4 │
            #  └-------------┴--┴---------------┘
            #V2>>>
            # CL_SLM_2 = 1.4
            # CL_SLM_Start_2 = 2
            # ADB_clip_limit = CL_SLM_Start_2/(i+1)**(i+CL_SLM_2) 
            # Try it in win graphing calculator copy and paste:
            #  ┌-----------------┬--┬-------------------┐
            #  │ 𝑦=2/(𝑥+1)^(𝑥+𝑉) ├OR┤ 𝑦=2/(𝑥+1)^(𝑥+1.4) │
            #  └-----------------┴--┴-------------------┘
        print(f'>   Generating ADB[{i+1}/{ADBD}]...')
        # prepare an iterators to scale images
        train_iterator = train_datagen.flow(x_train, y_train, batch_size=len(x_train))

        # get augmented data
        x_train_augmented, y_train_augmented = train_iterator.next()
        print(f'>   ├───Applying adaptive histogram equalization...')
        print(f'>   ├───Adaptive histogram equalization clip limit = {round(ADB_clip_limit, 2)}')
        x_train_augmented = np.clip(x_train_augmented, 0, 255) 
        #print_Color(f'~*>   |---Grayscale range: ~*Min = {np.min(x_train_augmented)}~* | ~*Max = {np.max(x_train_augmented)}', ['normal', 'blue', 'normal', 'red'], advanced_mode=True)
        x_train_augmented = apply_clahe_rgb_array(x_train_augmented, clip_limit=ADB_clip_limit) # compensating the image info loss
        print(f'>   └───Adding the Generated ADB...')
        # append augmented data to original data
        x_train = np.concatenate([x_train, x_train_augmented])
        y_train = np.concatenate([y_train, y_train_augmented])
        #free up memory
        del y_train_augmented
        del x_train_augmented
# normalizing 
print_Color('Normalizing image data...', ['yellow'])
if adjust_brightness_Mode:
    x_train = adjust_brightness(x_train, np.mean(x_train))
x_train = np.clip(x_train, 0, 255)  
x_train = np.array(x_train) / 255
y_train = np.array(y_train) 
if Make_EV_DATA:
    x_test = np.clip(x_test, 0, 255)  
    x_val = np.clip(x_val, 0, 255)  
    x_val = np.array(x_val)  / 255
    y_val = np.array(y_val)  
    x_test = np.array(x_test)  / 255
    y_test = np.array(y_test) 
# Check the range of image data
print_Color(f'~*Grayscale range: ~*Min = {np.min(x_train)}~* | ~*Max = {np.max(x_train)}', ['normal', 'blue', 'normal', 'red'], advanced_mode=True)
# Check the data type of image data
print_Color(f'~*Data type: ~*{x_train.dtype}', ['normal', 'green'], advanced_mode=True)
# Calculate the ratio of two labels
if categorical_IMP:
    label_ratio = np.sum(y_train[:, 0]) / np.sum(y_train[:, 1])
else:
    label_ratio = np.sum(y_train == 0) / (np.sum(y_train == 1) + 1e-10)
label_ratio_percentage = label_ratio * 100
print_Color(f'~*Label ratio: ~*{100 - label_ratio_percentage:.2f}% PNEUMONIA ~*| ~*{label_ratio_percentage:.2f}% NORMAL', ['normal', 'red', 'magenta', 'green'], advanced_mode=True)
print_Color('Setting LNTS...', ['yellow'])
# Get the total number of samples in the arrays
num_samples = x_train.shape[0]
print_Color(f'~*Original num_samples: ~*{num_samples}', ['normal', 'green'], advanced_mode=True)
if LNTS != 0:
    print_Color(f'~*Applying LNTS of: ~*{LNTS}', ['normal', 'green'], advanced_mode=True)
    print_Color(f'~*SNC: ~*{num_samples - LNTS}', ['normal', 'green'], advanced_mode=True)
    # Generate random indices to select LNTS samples
    indices = np.random.choice(num_samples, size=LNTS, replace=False)
    # Select the samples using the generated indices
    x_selected = x_train[indices]
    y_selected = y_train[indices]
    x_train = x_selected
    y_train = y_selected
    #free up memory
    del x_selected
    del y_selected
    del indices
    #Debug
    num_samples = x_train.shape[0]
    print_Color(f'~*New num_samples: ~*{num_samples}', ['normal', 'green'], advanced_mode=True)
# Shuffle the training data
print_Color('shuffling data...', ['yellow'])
x_train, y_train = shuffle_data(x_train, y_train)
#save_images_to_dir    
if Save_TS:
    print_Color('Saving TS...', ['yellow'])
    SITD = np.random.choice(num_samples, size=400, replace=False)
    S_dir = 'Samples/TSR400_' + datetime.datetime.now().strftime('y%Y_m%m_d%d-h%H_m%M_s%S')
    print_Color(f'~*Sample dir: ~*{S_dir}', ['normal', 'green'], advanced_mode=True)
    save_images_to_dir(x_train[SITD], y_train[SITD], S_dir)
print_Color('Done.', ['green'])
# Out:
# Using Def IDG...
# Found 5216 images belonging to 2 classes.
# Loading all images and labels into memory...
# Making categorical data...
# Generating augmented data [ADBD: 1]...
# >   Generating ADB[1/1]...
# >   ├───Applying adaptive histogram equalization...
# >   ├───Adaptive histogram equalization clip limit = 1.6
# >   └───Adding the Generated ADB...
# Normalizing image data...
# Grayscale range: Min = 0.0 | Max = 1.0
# Data type: float32
# Label ratio: 65.39% PNEUMONIA | 34.61% NORMAL
# Setting LNTS...
# Original num_samples: 10432
# shuffling data...
# Saving TS...
# Sample dir: Samples/TSR400_y2023_m10_d30-h17_m13_s01
# Done.

# %% [markdown]
# ## Save EV dataset

# %%
np.save(f'Database\\x_val{SL_EX}.npy', x_val)
np.save(f'Database\\y_val{SL_EX}.npy', y_val)
np.save(f'Database\\x_test{SL_EX}.npy', x_test)
np.save(f'Database\\y_test{SL_EX}.npy', y_test)

# %% [markdown]
# ## Load EV Dataset

# %%
x_val = np.load(f'Database\\x_val{SL_EX}.npy')
y_val = np.load(f'Database\\y_val{SL_EX}.npy')
x_test = np.load(f'Database\\x_test{SL_EX}.npy')
y_test = np.load(f'Database\\y_test{SL_EX}.npy')

# %% [markdown]
# ## Creating the model

# %% [markdown]
# ### V1
# ```
# statuses: Ready
# Working: ✅
# Model acc: 95.2
# type: transfer learning>>>(EfficientNetB7)
# ```

# %%
from keras.applications import EfficientNetB7

EfficientNet_M = EfficientNetB7(include_top=True, input_shape=(img_res[0], img_res[1], img_res[2]), weights=None, classes=2, classifier_activation='softmax')
# define new model
model = Model(inputs=EfficientNet_M.inputs, outputs=EfficientNet_M.outputs)

# compile model
opt = SGD(learning_rate=0.008, momentum=0.85, decay=0.001)
# opt = SGD(learning_rate=0.008, momentum=0.85, decay=0.001)
# opt = Adam()
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy', 'binary_accuracy'])

model.summary()

# %% [markdown]
# ### V1.1
# ```
# statuses: Test
# Working: ❌
# Model acc: N/A
# type: transfer learning>>>(ConvNeXtLarge)
# ```

# %%
from keras.applications import ConvNeXtXLarge
#FUNC
def CN_XL_NS(freeze_layers):
    base_model = ConvNeXtXLarge(input_shape=(img_res[0], img_res[1], img_res[2]), weights=None, include_top=False)
    print('Total layers in the base model: ', len(base_model.layers))
    print(f'Freezing {freeze_layers} layers in the base model...')
    # Freeze the specified number of layers
    for layer in base_model.layers[:-freeze_layers]:
        layer.trainable = False

    # Unfreeze the rest
    for layer in base_model.layers[-freeze_layers:]:
        layer.trainable = True

    # Calculate the percentage of the model that is frozen
    frozen_percentage = ((freeze_layers + 1e-10) / len(base_model.layers)) * 100
    print(f'Percentage of the base model that is frozen: {frozen_percentage:.2f}%')
    # adding CDL
    base_model_FT = GlobalAveragePooling2D()(base_model.output)
    Dense_L1 = Dense(2048, activation='relu', kernel_regularizer=l2(0.04))(base_model_FT)
    Dropout_L1 = Dropout(0.5)(Dense_L1) 
    BatchNorm_L2 = BatchNormalization()(Dropout_L1)
    Dense_L2 = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(BatchNorm_L2)
    BatchNorm_L3 = BatchNormalization()(Dense_L2)
    Dense_L3 = Dense(128, activation='relu')(BatchNorm_L3)
    predictions = Dense(2, activation='softmax')(Dense_L3)

    model_ConvNeXtXLarge_NS = Model(inputs=base_model.input, outputs=predictions)   
    print('Total model layers: ', len(model_ConvNeXtXLarge_NS.layers))
    #OPT/compile
    opt = SGD(momentum=0.9)
    model_ConvNeXtXLarge_NS.compile(optimizer = opt,  loss='categorical_crossentropy', metrics=['accuracy'])

    return model_ConvNeXtXLarge_NS
print('Creating the model...')
# Main
freeze_layers = 250
model = CN_XL_NS(freeze_layers)
model.summary(show_trainable=True, expand_nested=True)
print('done.')
# Out:
# Creating the model...
# Total layers in the base model:  295
# Freezing 250 layers in the base model...
# Percentage of the base model that is frozen: 84.75%
# Total model layers:  303
# Model: "model_2"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  input_4 (InputLayer)           [(None, 224, 224, 3  0           []                               N
#                                 )]
#
#  convnext_xlarge_prestem_normal  (None, 224, 224, 3)  0          ['input_4[0][0]']                N
#  ization (Normalization)
#
#  convnext_xlarge_stem (Sequenti  (None, 56, 56, 256)  13056      ['convnext_xlarge_prestem_norma  N
#  al)                                                             lization[0][0]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | convnext_xlarge_stem_conv (Con  (None, 56, 56, 256)  12544    []                               N          |
# | v2D)                                                                                                      |
# |                                                                                                           |
# | convnext_xlarge_stem_layernorm  (None, 56, 56, 256)  512      []                               N          |
# |  (LayerNormalization)                                                                                     |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  12800      ['convnext_xlarge_stem[0][0]']   N
#  0_depthwise_conv (Conv2D)
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  512        ['convnext_xlarge_stage_0_block  N
#  0_layernorm (LayerNormalizatio                                  _0_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 1024  263168     ['convnext_xlarge_stage_0_block  N
#  0_pointwise_conv_1 (Dense)     )                                _0_layernorm[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 1024  0          ['convnext_xlarge_stage_0_block  N
#  0_gelu (Activation)            )                                _0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  262400     ['convnext_xlarge_stage_0_block  N
#  0_pointwise_conv_2 (Dense)                                      _0_gelu[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  256        ['convnext_xlarge_stage_0_block  N
#  0_layer_scale (LayerScale)                                      _0_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  0          ['convnext_xlarge_stage_0_block  N
#  0_identity (Activation)                                         _0_layer_scale[0][0]']
#
#  tf.__operators__.add_72 (TFOpL  (None, 56, 56, 256)  0          ['convnext_xlarge_stem[0][0]',   N
#  ambda)                                                           'convnext_xlarge_stage_0_block
#                                                                  _0_identity[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  12800      ['tf.__operators__.add_72[0][0]  N
#  1_depthwise_conv (Conv2D)                                       ']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  512        ['convnext_xlarge_stage_0_block  N
#  1_layernorm (LayerNormalizatio                                  _1_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 1024  263168     ['convnext_xlarge_stage_0_block  N
#  1_pointwise_conv_1 (Dense)     )                                _1_layernorm[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 1024  0          ['convnext_xlarge_stage_0_block  N
#  1_gelu (Activation)            )                                _1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  262400     ['convnext_xlarge_stage_0_block  N
#  1_pointwise_conv_2 (Dense)                                      _1_gelu[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  256        ['convnext_xlarge_stage_0_block  N
#  1_layer_scale (LayerScale)                                      _1_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  0          ['convnext_xlarge_stage_0_block  N
#  1_identity (Activation)                                         _1_layer_scale[0][0]']
#
#  tf.__operators__.add_73 (TFOpL  (None, 56, 56, 256)  0          ['tf.__operators__.add_72[0][0]  N
#  ambda)                                                          ',
#                                                                   'convnext_xlarge_stage_0_block
#                                                                  _1_identity[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  12800      ['tf.__operators__.add_73[0][0]  N
#  2_depthwise_conv (Conv2D)                                       ']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  512        ['convnext_xlarge_stage_0_block  N
#  2_layernorm (LayerNormalizatio                                  _2_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 1024  263168     ['convnext_xlarge_stage_0_block  N
#  2_pointwise_conv_1 (Dense)     )                                _2_layernorm[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 1024  0          ['convnext_xlarge_stage_0_block  N
#  2_gelu (Activation)            )                                _2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  262400     ['convnext_xlarge_stage_0_block  N
#  2_pointwise_conv_2 (Dense)                                      _2_gelu[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  256        ['convnext_xlarge_stage_0_block  N
#  2_layer_scale (LayerScale)                                      _2_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_0_block_  (None, 56, 56, 256)  0          ['convnext_xlarge_stage_0_block  N
#  2_identity (Activation)                                         _2_layer_scale[0][0]']
#
#  tf.__operators__.add_74 (TFOpL  (None, 56, 56, 256)  0          ['tf.__operators__.add_73[0][0]  N
#  ambda)                                                          ',
#                                                                   'convnext_xlarge_stage_0_block
#                                                                  _2_identity[0][0]']
#
#  convnext_xlarge_downsampling_b  (None, 28, 28, 512)  525312     ['tf.__operators__.add_74[0][0]  N
#  lock_0 (Sequential)                                             ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | convnext_xlarge_downsampling_l  (None, 56, 56, 256)  512      []                               N          |
# | ayernorm_0 (LayerNormalization                                                                            |
# | )                                                                                                         |
# |                                                                                                           |
# | convnext_xlarge_downsampling_c  (None, 28, 28, 512)  524800   []                               N          |
# | onv_0 (Conv2D)                                                                                            |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  25600      ['convnext_xlarge_downsampling_  N
#  0_depthwise_conv (Conv2D)                                       block_0[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  1024       ['convnext_xlarge_stage_1_block  N
#  0_layernorm (LayerNormalizatio                                  _0_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 2048  1050624    ['convnext_xlarge_stage_1_block  N
#  0_pointwise_conv_1 (Dense)     )                                _0_layernorm[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 2048  0          ['convnext_xlarge_stage_1_block  N
#  0_gelu (Activation)            )                                _0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  1049088    ['convnext_xlarge_stage_1_block  N
#  0_pointwise_conv_2 (Dense)                                      _0_gelu[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  512        ['convnext_xlarge_stage_1_block  N
#  0_layer_scale (LayerScale)                                      _0_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  0          ['convnext_xlarge_stage_1_block  N
#  0_identity (Activation)                                         _0_layer_scale[0][0]']
#
#  tf.__operators__.add_75 (TFOpL  (None, 28, 28, 512)  0          ['convnext_xlarge_downsampling_  N
#  ambda)                                                          block_0[0][0]',
#                                                                   'convnext_xlarge_stage_1_block
#                                                                  _0_identity[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  25600      ['tf.__operators__.add_75[0][0]  N
#  1_depthwise_conv (Conv2D)                                       ']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  1024       ['convnext_xlarge_stage_1_block  N
#  1_layernorm (LayerNormalizatio                                  _1_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 2048  1050624    ['convnext_xlarge_stage_1_block  N
#  1_pointwise_conv_1 (Dense)     )                                _1_layernorm[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 2048  0          ['convnext_xlarge_stage_1_block  N
#  1_gelu (Activation)            )                                _1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  1049088    ['convnext_xlarge_stage_1_block  N
#  1_pointwise_conv_2 (Dense)                                      _1_gelu[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  512        ['convnext_xlarge_stage_1_block  N
#  1_layer_scale (LayerScale)                                      _1_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  0          ['convnext_xlarge_stage_1_block  N
#  1_identity (Activation)                                         _1_layer_scale[0][0]']
#
#  tf.__operators__.add_76 (TFOpL  (None, 28, 28, 512)  0          ['tf.__operators__.add_75[0][0]  N
#  ambda)                                                          ',
#                                                                   'convnext_xlarge_stage_1_block
#                                                                  _1_identity[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  25600      ['tf.__operators__.add_76[0][0]  N
#  2_depthwise_conv (Conv2D)                                       ']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  1024       ['convnext_xlarge_stage_1_block  Y
#  2_layernorm (LayerNormalizatio                                  _2_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 2048  1050624    ['convnext_xlarge_stage_1_block  Y
#  2_pointwise_conv_1 (Dense)     )                                _2_layernorm[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 2048  0          ['convnext_xlarge_stage_1_block  Y
#  2_gelu (Activation)            )                                _2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  1049088    ['convnext_xlarge_stage_1_block  Y
#  2_pointwise_conv_2 (Dense)                                      _2_gelu[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  512        ['convnext_xlarge_stage_1_block  Y
#  2_layer_scale (LayerScale)                                      _2_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_1_block_  (None, 28, 28, 512)  0          ['convnext_xlarge_stage_1_block  Y
#  2_identity (Activation)                                         _2_layer_scale[0][0]']
#
#  tf.__operators__.add_77 (TFOpL  (None, 28, 28, 512)  0          ['tf.__operators__.add_76[0][0]  Y
#  ambda)                                                          ',
#                                                                   'convnext_xlarge_stage_1_block
#                                                                  _2_identity[0][0]']
#
#  convnext_xlarge_downsampling_b  (None, 14, 14, 1024  2099200    ['tf.__operators__.add_77[0][0]  Y
#  lock_1 (Sequential)            )                                ']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | convnext_xlarge_downsampling_l  (None, 28, 28, 512)  1024     []                               Y          |
# | ayernorm_1 (LayerNormalization                                                                            |
# | )                                                                                                         |
# |                                                                                                           |
# | convnext_xlarge_downsampling_c  (None, 14, 14, 1024  2098176  []                               Y          |
# | onv_1 (Conv2D)               )                                                                            |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['convnext_xlarge_downsampling_  Y
#  0_depthwise_conv (Conv2D)      )                                block_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  0_layernorm (LayerNormalizatio  )                               _0_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  0_pointwise_conv_1 (Dense)     )                                _0_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  0_gelu (Activation)            )                                _0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  0_pointwise_conv_2 (Dense)     )                                _0_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  0_layer_scale (LayerScale)     )                                _0_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  0_identity (Activation)        )                                _0_layer_scale[0][0]']
#
#  tf.__operators__.add_78 (TFOpL  (None, 14, 14, 1024  0          ['convnext_xlarge_downsampling_  Y
#  ambda)                         )                                block_1[0][0]',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _0_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_78[0][0]  Y
#  1_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  1_layernorm (LayerNormalizatio  )                               _1_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  1_pointwise_conv_1 (Dense)     )                                _1_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  1_gelu (Activation)            )                                _1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  1_pointwise_conv_2 (Dense)     )                                _1_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  1_layer_scale (LayerScale)     )                                _1_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  1_identity (Activation)        )                                _1_layer_scale[0][0]']
#
#  tf.__operators__.add_79 (TFOpL  (None, 14, 14, 1024  0          ['tf.__operators__.add_78[0][0]  Y
#  ambda)                         )                                ',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _1_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_79[0][0]  Y
#  2_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  2_layernorm (LayerNormalizatio  )                               _2_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  2_pointwise_conv_1 (Dense)     )                                _2_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  2_gelu (Activation)            )                                _2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  2_pointwise_conv_2 (Dense)     )                                _2_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  2_layer_scale (LayerScale)     )                                _2_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  2_identity (Activation)        )                                _2_layer_scale[0][0]']
#
#  tf.__operators__.add_80 (TFOpL  (None, 14, 14, 1024  0          ['tf.__operators__.add_79[0][0]  Y
#  ambda)                         )                                ',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _2_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_80[0][0]  Y
#  3_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  3_layernorm (LayerNormalizatio  )                               _3_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  3_pointwise_conv_1 (Dense)     )                                _3_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  3_gelu (Activation)            )                                _3_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  3_pointwise_conv_2 (Dense)     )                                _3_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  3_layer_scale (LayerScale)     )                                _3_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  3_identity (Activation)        )                                _3_layer_scale[0][0]']
#
#  tf.__operators__.add_81 (TFOpL  (None, 14, 14, 1024  0          ['tf.__operators__.add_80[0][0]  Y
#  ambda)                         )                                ',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _3_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_81[0][0]  Y
#  4_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  4_layernorm (LayerNormalizatio  )                               _4_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  4_pointwise_conv_1 (Dense)     )                                _4_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  4_gelu (Activation)            )                                _4_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  4_pointwise_conv_2 (Dense)     )                                _4_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  4_layer_scale (LayerScale)     )                                _4_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  4_identity (Activation)        )                                _4_layer_scale[0][0]']
#
#  tf.__operators__.add_82 (TFOpL  (None, 14, 14, 1024  0          ['tf.__operators__.add_81[0][0]  Y
#  ambda)                         )                                ',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _4_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_82[0][0]  Y
#  5_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  5_layernorm (LayerNormalizatio  )                               _5_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  5_pointwise_conv_1 (Dense)     )                                _5_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  5_gelu (Activation)            )                                _5_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  5_pointwise_conv_2 (Dense)     )                                _5_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  5_layer_scale (LayerScale)     )                                _5_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  5_identity (Activation)        )                                _5_layer_scale[0][0]']
#
#  tf.__operators__.add_83 (TFOpL  (None, 14, 14, 1024  0          ['tf.__operators__.add_82[0][0]  Y
#  ambda)                         )                                ',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _5_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_83[0][0]  Y
#  6_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  6_layernorm (LayerNormalizatio  )                               _6_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  6_pointwise_conv_1 (Dense)     )                                _6_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  6_gelu (Activation)            )                                _6_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  6_pointwise_conv_2 (Dense)     )                                _6_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  6_layer_scale (LayerScale)     )                                _6_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  6_identity (Activation)        )                                _6_layer_scale[0][0]']
#
#  tf.__operators__.add_84 (TFOpL  (None, 14, 14, 1024  0          ['tf.__operators__.add_83[0][0]  Y
#  ambda)                         )                                ',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _6_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_84[0][0]  Y
#  7_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  7_layernorm (LayerNormalizatio  )                               _7_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  7_pointwise_conv_1 (Dense)     )                                _7_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  7_gelu (Activation)            )                                _7_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  7_pointwise_conv_2 (Dense)     )                                _7_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  7_layer_scale (LayerScale)     )                                _7_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  7_identity (Activation)        )                                _7_layer_scale[0][0]']
#
#  tf.__operators__.add_85 (TFOpL  (None, 14, 14, 1024  0          ['tf.__operators__.add_84[0][0]  Y
#  ambda)                         )                                ',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _7_identity[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_85[0][0]  Y
#  8_depthwise_conv (Conv2D)      )                                ']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  8_layernorm (LayerNormalizatio  )                               _8_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  8_pointwise_conv_1 (Dense)     )                                _8_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  8_gelu (Activation)            )                                _8_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  8_pointwise_conv_2 (Dense)     )                                _8_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  8_layer_scale (LayerScale)     )                                _8_pointwise_conv_2[0][0]']
#
# ...
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  51200      ['tf.__operators__.add_103[0][0  Y
#  26_depthwise_conv (Conv2D)     )                                ]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  2048       ['convnext_xlarge_stage_2_block  Y
#  26_layernorm (LayerNormalizati  )                               _26_depthwise_conv[0][0]']
#  on)
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  4198400    ['convnext_xlarge_stage_2_block  Y
#  26_pointwise_conv_1 (Dense)    )                                _26_layernorm[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 4096  0          ['convnext_xlarge_stage_2_block  Y
#  26_gelu (Activation)           )                                _26_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  4195328    ['convnext_xlarge_stage_2_block  Y
#  26_pointwise_conv_2 (Dense)    )                                _26_gelu[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  1024       ['convnext_xlarge_stage_2_block  Y
#  26_layer_scale (LayerScale)    )                                _26_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_2_block_  (None, 14, 14, 1024  0          ['convnext_xlarge_stage_2_block  Y
#  26_identity (Activation)       )                                _26_layer_scale[0][0]']
#
#  tf.__operators__.add_104 (TFOp  (None, 14, 14, 1024  0          ['tf.__operators__.add_103[0][0  Y
#  Lambda)                        )                                ]',
#                                                                   'convnext_xlarge_stage_2_block
#                                                                  _26_identity[0][0]']
#
#  convnext_xlarge_downsampling_b  (None, 7, 7, 2048)  8392704     ['tf.__operators__.add_104[0][0  Y
#  lock_2 (Sequential)                                             ]']
# |¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯|
# | convnext_xlarge_downsampling_l  (None, 14, 14, 1024  2048     []                               Y          |
# | ayernorm_2 (LayerNormalization  )                                                                         |
# | )                                                                                                         |
# |                                                                                                           |
# | convnext_xlarge_downsampling_c  (None, 7, 7, 2048)  8390656   []                               Y          |
# | onv_2 (Conv2D)                                                                                            |
# ¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯¯
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  102400      ['convnext_xlarge_downsampling_  Y
#  0_depthwise_conv (Conv2D)                                       block_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  4096        ['convnext_xlarge_stage_3_block  Y
#  0_layernorm (LayerNormalizatio                                  _0_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 8192)  16785408    ['convnext_xlarge_stage_3_block  Y
#  0_pointwise_conv_1 (Dense)                                      _0_layernorm[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 8192)  0           ['convnext_xlarge_stage_3_block  Y
#  0_gelu (Activation)                                             _0_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  16779264    ['convnext_xlarge_stage_3_block  Y
#  0_pointwise_conv_2 (Dense)                                      _0_gelu[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  2048        ['convnext_xlarge_stage_3_block  Y
#  0_layer_scale (LayerScale)                                      _0_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  0           ['convnext_xlarge_stage_3_block  Y
#  0_identity (Activation)                                         _0_layer_scale[0][0]']
#
#  tf.__operators__.add_105 (TFOp  (None, 7, 7, 2048)  0           ['convnext_xlarge_downsampling_  Y
#  Lambda)                                                         block_2[0][0]',
#                                                                   'convnext_xlarge_stage_3_block
#                                                                  _0_identity[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  102400      ['tf.__operators__.add_105[0][0  Y
#  1_depthwise_conv (Conv2D)                                       ]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  4096        ['convnext_xlarge_stage_3_block  Y
#  1_layernorm (LayerNormalizatio                                  _1_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 8192)  16785408    ['convnext_xlarge_stage_3_block  Y
#  1_pointwise_conv_1 (Dense)                                      _1_layernorm[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 8192)  0           ['convnext_xlarge_stage_3_block  Y
#  1_gelu (Activation)                                             _1_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  16779264    ['convnext_xlarge_stage_3_block  Y
#  1_pointwise_conv_2 (Dense)                                      _1_gelu[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  2048        ['convnext_xlarge_stage_3_block  Y
#  1_layer_scale (LayerScale)                                      _1_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  0           ['convnext_xlarge_stage_3_block  Y
#  1_identity (Activation)                                         _1_layer_scale[0][0]']
#
#  tf.__operators__.add_106 (TFOp  (None, 7, 7, 2048)  0           ['tf.__operators__.add_105[0][0  Y
#  Lambda)                                                         ]',
#                                                                   'convnext_xlarge_stage_3_block
#                                                                  _1_identity[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  102400      ['tf.__operators__.add_106[0][0  Y
#  2_depthwise_conv (Conv2D)                                       ]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  4096        ['convnext_xlarge_stage_3_block  Y
#  2_layernorm (LayerNormalizatio                                  _2_depthwise_conv[0][0]']
#  n)
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 8192)  16785408    ['convnext_xlarge_stage_3_block  Y
#  2_pointwise_conv_1 (Dense)                                      _2_layernorm[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 8192)  0           ['convnext_xlarge_stage_3_block  Y
#  2_gelu (Activation)                                             _2_pointwise_conv_1[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  16779264    ['convnext_xlarge_stage_3_block  Y
#  2_pointwise_conv_2 (Dense)                                      _2_gelu[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  2048        ['convnext_xlarge_stage_3_block  Y
#  2_layer_scale (LayerScale)                                      _2_pointwise_conv_2[0][0]']
#
#  convnext_xlarge_stage_3_block_  (None, 7, 7, 2048)  0           ['convnext_xlarge_stage_3_block  Y
#  2_identity (Activation)                                         _2_layer_scale[0][0]']
#
#  tf.__operators__.add_107 (TFOp  (None, 7, 7, 2048)  0           ['tf.__operators__.add_106[0][0  Y
#  Lambda)                                                         ]',
#                                                                   'convnext_xlarge_stage_3_block
#                                                                  _2_identity[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 7, 7, 2048)  4096        ['tf.__operators__.add_107[0][0  Y
#  rmalization)                                                    ]']
#
#  global_average_pooling2d_2 (Gl  (None, 2048)        0           ['layer_normalization_2[0][0]']  Y
#  obalAveragePooling2D)
#
#  dense_8 (Dense)                (None, 2048)         4196352     ['global_average_pooling2d_2[0]  Y
#                                                                  [0]']
#
#  dropout_2 (Dropout)            (None, 2048)         0           ['dense_8[0][0]']                Y
#
#  batch_normalization_4 (BatchNo  (None, 2048)        8192        ['dropout_2[0][0]']              Y
#  rmalization)
#
#  dense_9 (Dense)                (None, 512)          1049088     ['batch_normalization_4[0][0]']  Y
#
#  batch_normalization_5 (BatchNo  (None, 512)         2048        ['dense_9[0][0]']                Y
#  rmalization)
#
#  dense_10 (Dense)               (None, 128)          65664       ['batch_normalization_5[0][0]']  Y
#
#  dense_11 (Dense)               (None, 2)            258         ['dense_10[0][0]']               Y
#
# =============================================================================================================
# Total params: 353,469,570
# Trainable params: 347,029,378
# Non-trainable params: 6,440,192
# _____________________________________________________________________________________________________________
# done.

# %% [markdown]
# ### V1.2 (Super Ai model)
# ```
# statuses: Test
# Working: ✅
# Model acc: 95.3
# type: transfer learning>>>(EfficientNetB7::CCL)
# ```

# %%
from efficientnet.keras import EfficientNetB7 as KENB7
#FUNC
def Eff_B7_NS(freeze_layers):
    base_model = KENB7(input_shape=(img_res[0], img_res[1], img_res[2]), weights='noisy-student', include_top=False)
    print('Total layers in the base model: ', len(base_model.layers))
    print(f'Freezing {freeze_layers} layers in the base model...')
    # Freeze the specified number of layers
    for layer in base_model.layers[:-freeze_layers]:
        layer.trainable = False

    # Unfreeze the rest
    for layer in base_model.layers[-freeze_layers:]:
        layer.trainable = True

    # Calculate the percentage of the model that is frozen
    frozen_percentage = ((freeze_layers + 1e-10) / len(base_model.layers)) * 100
    print(f'Percentage of the base model that is frozen: {frozen_percentage:.2f}%')
    # adding CDL
    base_model_FT = GlobalAveragePooling2D()(base_model.output)
    Dense_L1 = Dense(2048, activation='relu', kernel_regularizer=l2(0.04))(base_model_FT)
    Dropout_L1 = Dropout(0.5)(Dense_L1) 
    BatchNorm_L2 = BatchNormalization()(Dropout_L1)
    Dense_L2 = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(BatchNorm_L2)
    BatchNorm_L3 = BatchNormalization()(Dense_L2)
    Dense_L3 = Dense(128, activation='relu')(BatchNorm_L3)
    predictions = Dense(2, activation='softmax')(Dense_L3)

    model_EfficientNetB7_NS = Model(inputs=base_model.input, outputs=predictions)   
    print('Total model layers: ', len(model_EfficientNetB7_NS.layers))
    #OPT/compile
    opt = SGD(momentum=0.9)
    model_EfficientNetB7_NS.compile(optimizer = opt,  loss='categorical_crossentropy', metrics=['accuracy'])

    return model_EfficientNetB7_NS
print('Creating the model...')
# Main
freeze_layers = 400
model = Eff_B7_NS(freeze_layers)
model.summary(show_trainable=True, expand_nested=True)
print('done.')
# Out:
# Model: "model_3"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  EfficientNetB7_0 (InputLayer)  [(None, 224, 224, 3  0           []                               Y
#                                 )]
#
#  EfficientNetB7_1 (Rescaling)   (None, 224, 224, 3)  0           ['EfficientNetB7_0[0][0]']       Y
#
#  EfficientNetB7_2 (Normalizatio  (None, 224, 224, 3)  7          ['EfficientNetB7_1[0][0]']       Y
#  n)
#
#  EfficientNetB7_3 (ZeroPadding2  (None, 225, 225, 3)  0          ['EfficientNetB7_2[0][0]']       Y
#  D)
#
#  EfficientNetB7_4 (Conv2D)      (None, 112, 112, 64  1728        ['EfficientNetB7_3[0][0]']       Y
#                                 )
#
#  EfficientNetB7_5 (BatchNormali  (None, 112, 112, 64  256        ['EfficientNetB7_4[0][0]']       Y
#  zation)                        )
#
#  EfficientNetB7_6 (Activation)  (None, 112, 112, 64  0           ['EfficientNetB7_5[0][0]']       Y
#                                 )
#
#  EfficientNetB7_7 (DepthwiseCon  (None, 112, 112, 64  576        ['EfficientNetB7_6[0][0]']       Y
#  v2D)                           )
#
#  EfficientNetB7_8 (BatchNormali  (None, 112, 112, 64  256        ['EfficientNetB7_7[0][0]']       Y
#  zation)                        )
#
#  EfficientNetB7_9 (Activation)  (None, 112, 112, 64  0           ['EfficientNetB7_8[0][0]']       Y
#                                 )
#
#  EfficientNetB7_10 (GlobalAvera  (None, 64)          0           ['EfficientNetB7_9[0][0]']       Y
#  gePooling2D)
#
#  EfficientNetB7_11 (Reshape)    (None, 1, 1, 64)     0           ['EfficientNetB7_10[0][0]']      Y
#
#  EfficientNetB7_12 (Conv2D)     (None, 1, 1, 16)     1040        ['EfficientNetB7_11[0][0]']      Y
#
#  EfficientNetB7_13 (Conv2D)     (None, 1, 1, 64)     1088        ['EfficientNetB7_12[0][0]']      Y
#
#  EfficientNetB7_14 (Multiply)   (None, 112, 112, 64  0           ['EfficientNetB7_9[0][0]',       Y
#                                 )                                 'EfficientNetB7_13[0][0]']
#
#  EfficientNetB7_15 (Conv2D)     (None, 112, 112, 32  2048        ['EfficientNetB7_14[0][0]']      Y
#                                 )
#
#  EfficientNetB7_16 (BatchNormal  (None, 112, 112, 32  128        ['EfficientNetB7_15[0][0]']      Y
#  ization)                       )
#
#  EfficientNetB7_17 (DepthwiseCo  (None, 112, 112, 32  288        ['EfficientNetB7_16[0][0]']      Y
#  nv2D)                          )
#
#  EfficientNetB7_18 (BatchNormal  (None, 112, 112, 32  128        ['EfficientNetB7_17[0][0]']      Y
#  ization)                       )
#
#  EfficientNetB7_19 (Activation)  (None, 112, 112, 32  0          ['EfficientNetB7_18[0][0]']      Y
#                                 )
#
#  EfficientNetB7_20 (GlobalAvera  (None, 32)          0           ['EfficientNetB7_19[0][0]']      Y
#  gePooling2D)
#
#  EfficientNetB7_21 (Reshape)    (None, 1, 1, 32)     0           ['EfficientNetB7_20[0][0]']      Y
#
#  EfficientNetB7_22 (Conv2D)     (None, 1, 1, 8)      264         ['EfficientNetB7_21[0][0]']      Y
#
#  EfficientNetB7_23 (Conv2D)     (None, 1, 1, 32)     288         ['EfficientNetB7_22[0][0]']      Y
#
#  EfficientNetB7_24 (Multiply)   (None, 112, 112, 32  0           ['EfficientNetB7_19[0][0]',      Y
#                                 )                                 'EfficientNetB7_23[0][0]']
#
#  EfficientNetB7_25 (Conv2D)     (None, 112, 112, 32  1024        ['EfficientNetB7_24[0][0]']      Y
#                                 )
#
#  EfficientNetB7_26 (BatchNormal  (None, 112, 112, 32  128        ['EfficientNetB7_25[0][0]']      Y
#  ization)                       )
#
#  EfficientNetB7_27 (Dropout)    (None, 112, 112, 32  0           ['EfficientNetB7_26[0][0]']      Y
#                                 )
#
#  EfficientNetB7_28 (Add)        (None, 112, 112, 32  0           ['EfficientNetB7_27[0][0]',      Y
#                                 )                                 'EfficientNetB7_16[0][0]']
#
#  EfficientNetB7_29 (DepthwiseCo  (None, 112, 112, 32  288        ['EfficientNetB7_28[0][0]']      Y
#  nv2D)                          )
#
#  EfficientNetB7_30 (BatchNormal  (None, 112, 112, 32  128        ['EfficientNetB7_29[0][0]']      Y
#  ization)                       )
#
#  EfficientNetB7_31 (Activation)  (None, 112, 112, 32  0          ['EfficientNetB7_30[0][0]']      Y
#                                 )
#
#  EfficientNetB7_32 (GlobalAvera  (None, 32)          0           ['EfficientNetB7_31[0][0]']      Y
#  gePooling2D)
#
#  EfficientNetB7_33 (Reshape)    (None, 1, 1, 32)     0           ['EfficientNetB7_32[0][0]']      Y
#
#  EfficientNetB7_34 (Conv2D)     (None, 1, 1, 8)      264         ['EfficientNetB7_33[0][0]']      Y
#
#  EfficientNetB7_35 (Conv2D)     (None, 1, 1, 32)     288         ['EfficientNetB7_34[0][0]']      Y
#
#  EfficientNetB7_36 (Multiply)   (None, 112, 112, 32  0           ['EfficientNetB7_31[0][0]',      Y
#                                 )                                 'EfficientNetB7_35[0][0]']
#
#  EfficientNetB7_37 (Conv2D)     (None, 112, 112, 32  1024        ['EfficientNetB7_36[0][0]']      Y
#                                 )
#
#  EfficientNetB7_38 (BatchNormal  (None, 112, 112, 32  128        ['EfficientNetB7_37[0][0]']      Y
#  ization)                       )
#
#  EfficientNetB7_39 (Dropout)    (None, 112, 112, 32  0           ['EfficientNetB7_38[0][0]']      Y
#                                 )
#
#  EfficientNetB7_40 (Add)        (None, 112, 112, 32  0           ['EfficientNetB7_39[0][0]',      Y
#                                 )                                 'EfficientNetB7_28[0][0]']
#
#  EfficientNetB7_41 (DepthwiseCo  (None, 112, 112, 32  288        ['EfficientNetB7_40[0][0]']      Y
#  nv2D)                          )
#
#  EfficientNetB7_42 (BatchNormal  (None, 112, 112, 32  128        ['EfficientNetB7_41[0][0]']      Y
#  ization)                       )
#
#  EfficientNetB7_43 (Activation)  (None, 112, 112, 32  0          ['EfficientNetB7_42[0][0]']      Y
#                                 )
#
#  EfficientNetB7_44 (GlobalAvera  (None, 32)          0           ['EfficientNetB7_43[0][0]']      Y
#  gePooling2D)
#
#  EfficientNetB7_45 (Reshape)    (None, 1, 1, 32)     0           ['EfficientNetB7_44[0][0]']      Y
#
#  EfficientNetB7_46 (Conv2D)     (None, 1, 1, 8)      264         ['EfficientNetB7_45[0][0]']      Y
#
#  EfficientNetB7_47 (Conv2D)     (None, 1, 1, 32)     288         ['EfficientNetB7_46[0][0]']      Y
#
#  EfficientNetB7_48 (Multiply)   (None, 112, 112, 32  0           ['EfficientNetB7_43[0][0]',      Y
#                                 )                                 'EfficientNetB7_47[0][0]']
#
#  EfficientNetB7_49 (Conv2D)     (None, 112, 112, 32  1024        ['EfficientNetB7_48[0][0]']      Y
#                                 )
#
#  EfficientNetB7_50 (BatchNormal  (None, 112, 112, 32  128        ['EfficientNetB7_49[0][0]']      Y
#  ization)                       )
#
#  EfficientNetB7_51 (Dropout)    (None, 112, 112, 32  0           ['EfficientNetB7_50[0][0]']      Y
#                                 )
#
#  EfficientNetB7_52 (Add)        (None, 112, 112, 32  0           ['EfficientNetB7_51[0][0]',      Y
#                                 )                                 'EfficientNetB7_40[0][0]']
#
#  EfficientNetB7_53 (Conv2D)     (None, 112, 112, 19  6144        ['EfficientNetB7_52[0][0]']      Y
#                                 2)
#
#  EfficientNetB7_54 (BatchNormal  (None, 112, 112, 19  768        ['EfficientNetB7_53[0][0]']      Y
#  ization)                       2)
#
#  EfficientNetB7_55 (Activation)  (None, 112, 112, 19  0          ['EfficientNetB7_54[0][0]']      Y
#                                 2)
#
#  EfficientNetB7_56 (ZeroPadding  (None, 113, 113, 19  0          ['EfficientNetB7_55[0][0]']      Y
#  2D)                            2)
#
#  EfficientNetB7_57 (DepthwiseCo  (None, 56, 56, 192)  1728       ['EfficientNetB7_56[0][0]']      Y
#  nv2D)
#
#  EfficientNetB7_58 (BatchNormal  (None, 56, 56, 192)  768        ['EfficientNetB7_57[0][0]']      Y
#  ization)
#
#  EfficientNetB7_59 (Activation)  (None, 56, 56, 192)  0          ['EfficientNetB7_58[0][0]']      Y
#
#  EfficientNetB7_60 (GlobalAvera  (None, 192)         0           ['EfficientNetB7_59[0][0]']      Y
#  gePooling2D)
#
#  EfficientNetB7_61 (Reshape)    (None, 1, 1, 192)    0           ['EfficientNetB7_60[0][0]']      Y
#
#  EfficientNetB7_62 (Conv2D)     (None, 1, 1, 8)      1544        ['EfficientNetB7_61[0][0]']      Y
#
#  EfficientNetB7_63 (Conv2D)     (None, 1, 1, 192)    1728        ['EfficientNetB7_62[0][0]']      Y
#
#  EfficientNetB7_64 (Multiply)   (None, 56, 56, 192)  0           ['EfficientNetB7_59[0][0]',      Y
#                                                                   'EfficientNetB7_63[0][0]']
#
#  EfficientNetB7_65 (Conv2D)     (None, 56, 56, 48)   9216        ['EfficientNetB7_64[0][0]']      Y
#
#  EfficientNetB7_66 (BatchNormal  (None, 56, 56, 48)  192         ['EfficientNetB7_65[0][0]']      Y
#  ization)
#
#  EfficientNetB7_67 (Conv2D)     (None, 56, 56, 288)  13824       ['EfficientNetB7_66[0][0]']      Y
#
#  EfficientNetB7_68 (BatchNormal  (None, 56, 56, 288)  1152       ['EfficientNetB7_67[0][0]']      Y
#  ization)
#
#  EfficientNetB7_69 (Activation)  (None, 56, 56, 288)  0          ['EfficientNetB7_68[0][0]']      Y
#
#  EfficientNetB7_70 (DepthwiseCo  (None, 56, 56, 288)  2592       ['EfficientNetB7_69[0][0]']      Y
#  nv2D)
#
#  EfficientNetB7_71 (BatchNormal  (None, 56, 56, 288)  1152       ['EfficientNetB7_70[0][0]']      Y
#  ization)
#
#  EfficientNetB7_72 (Activation)  (None, 56, 56, 288)  0          ['EfficientNetB7_71[0][0]']      Y
#
#  EfficientNetB7_73 (GlobalAvera  (None, 288)         0           ['EfficientNetB7_72[0][0]']      Y
#  gePooling2D)
#
#  EfficientNetB7_74 (Reshape)    (None, 1, 1, 288)    0           ['EfficientNetB7_73[0][0]']      Y
#
#  EfficientNetB7_75 (Conv2D)     (None, 1, 1, 12)     3468        ['EfficientNetB7_74[0][0]']      Y
#
#  EfficientNetB7_76 (Conv2D)     (None, 1, 1, 288)    3744        ['EfficientNetB7_75[0][0]']      Y
#
#  EfficientNetB7_77 (Multiply)   (None, 56, 56, 288)  0           ['EfficientNetB7_72[0][0]',      Y
#                                                                   'EfficientNetB7_76[0][0]']
#
#  EfficientNetB7_78 (Conv2D)     (None, 56, 56, 48)   13824       ['EfficientNetB7_77[0][0]']      Y
#
#  EfficientNetB7_79 (BatchNormal  (None, 56, 56, 48)  192         ['EfficientNetB7_78[0][0]']      Y
#  ization)
#
#  EfficientNetB7_80 (Dropout)    (None, 56, 56, 48)   0           ['EfficientNetB7_79[0][0]']      Y
#
#  EfficientNetB7_81 (Add)        (None, 56, 56, 48)   0           ['EfficientNetB7_80[0][0]',      Y
#                                                                   'EfficientNetB7_66[0][0]']
#
#  EfficientNetB7_82 (Conv2D)     (None, 56, 56, 288)  13824       ['EfficientNetB7_81[0][0]']      Y
#
#  EfficientNetB7_83 (BatchNormal  (None, 56, 56, 288)  1152       ['EfficientNetB7_82[0][0]']      Y
#  ization)
#
#  EfficientNetB7_84 (Activation)  (None, 56, 56, 288)  0          ['EfficientNetB7_83[0][0]']      Y
#
#  EfficientNetB7_85 (DepthwiseCo  (None, 56, 56, 288)  2592       ['EfficientNetB7_84[0][0]']      Y
#  nv2D)
#
#  EfficientNetB7_86 (BatchNormal  (None, 56, 56, 288)  1152       ['EfficientNetB7_85[0][0]']      Y
#  ization)
#
#  EfficientNetB7_87 (Activation)  (None, 56, 56, 288)  0          ['EfficientNetB7_86[0][0]']      Y
#
#  EfficientNetB7_88 (GlobalAvera  (None, 288)         0           ['EfficientNetB7_87[0][0]']      Y
#  gePooling2D)
#
#  EfficientNetB7_89 (Reshape)    (None, 1, 1, 288)    0           ['EfficientNetB7_88[0][0]']      Y
#
#  EfficientNetB7_90 (Conv2D)     (None, 1, 1, 12)     3468        ['EfficientNetB7_89[0][0]']      Y
#
#  EfficientNetB7_91 (Conv2D)     (None, 1, 1, 288)    3744        ['EfficientNetB7_90[0][0]']      Y
#
#  EfficientNetB7_92 (Multiply)   (None, 56, 56, 288)  0           ['EfficientNetB7_87[0][0]',      Y
#                                                                   'EfficientNetB7_91[0][0]']
#
#  EfficientNetB7_93 (Conv2D)     (None, 56, 56, 48)   13824       ['EfficientNetB7_92[0][0]']      Y
#
#  EfficientNetB7_94 (BatchNormal  (None, 56, 56, 48)  192         ['EfficientNetB7_93[0][0]']      Y
#  ization)
#
#  EfficientNetB7_95 (Dropout)    (None, 56, 56, 48)   0           ['EfficientNetB7_94[0][0]']      Y
#
#  EfficientNetB7_96 (Add)        (None, 56, 56, 48)   0           ['EfficientNetB7_95[0][0]',      Y
#                                                                   'EfficientNetB7_81[0][0]']
#
#  EfficientNetB7_97 (Conv2D)     (None, 56, 56, 288)  13824       ['EfficientNetB7_96[0][0]']      Y
#
#  EfficientNetB7_98 (BatchNormal  (None, 56, 56, 288)  1152       ['EfficientNetB7_97[0][0]']      Y
#  ization)
#
#  EfficientNetB7_99 (Activation)  (None, 56, 56, 288)  0          ['EfficientNetB7_98[0][0]']      Y
#
#  EfficientNetB7_100 (DepthwiseC  (None, 56, 56, 288)  2592       ['EfficientNetB7_99[0][0]']      Y
#  onv2D)
#
#  EfficientNetB7_101 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_100[0][0]']     Y
#  lization)
#
#  EfficientNetB7_102 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_101[0][0]']     Y
#  )
#
#  EfficientNetB7_103 (GlobalAver  (None, 288)         0           ['EfficientNetB7_102[0][0]']     Y
#  agePooling2D)
#
#  EfficientNetB7_104 (Reshape)   (None, 1, 1, 288)    0           ['EfficientNetB7_103[0][0]']     Y
#
#  EfficientNetB7_105 (Conv2D)    (None, 1, 1, 12)     3468        ['EfficientNetB7_104[0][0]']     Y
#
#  EfficientNetB7_106 (Conv2D)    (None, 1, 1, 288)    3744        ['EfficientNetB7_105[0][0]']     Y
#
#  EfficientNetB7_107 (Multiply)  (None, 56, 56, 288)  0           ['EfficientNetB7_102[0][0]',     Y
#                                                                   'EfficientNetB7_106[0][0]']
#
#  EfficientNetB7_108 (Conv2D)    (None, 56, 56, 48)   13824       ['EfficientNetB7_107[0][0]']     Y
#
#  EfficientNetB7_109 (BatchNorma  (None, 56, 56, 48)  192         ['EfficientNetB7_108[0][0]']     Y
#  lization)
#
#  EfficientNetB7_110 (Dropout)   (None, 56, 56, 48)   0           ['EfficientNetB7_109[0][0]']     Y
#
#  EfficientNetB7_111 (Add)       (None, 56, 56, 48)   0           ['EfficientNetB7_110[0][0]',     Y
#                                                                   'EfficientNetB7_96[0][0]']
#
#  EfficientNetB7_112 (Conv2D)    (None, 56, 56, 288)  13824       ['EfficientNetB7_111[0][0]']     Y
#
#  EfficientNetB7_113 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_112[0][0]']     Y
#  lization)
#
#  EfficientNetB7_114 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_113[0][0]']     Y
#  )
#
#  EfficientNetB7_115 (DepthwiseC  (None, 56, 56, 288)  2592       ['EfficientNetB7_114[0][0]']     Y
#  onv2D)
#
#  EfficientNetB7_116 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_115[0][0]']     Y
#  lization)
#
#  EfficientNetB7_117 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_116[0][0]']     Y
#  )
#
#  EfficientNetB7_118 (GlobalAver  (None, 288)         0           ['EfficientNetB7_117[0][0]']     Y
#  agePooling2D)
#
#  EfficientNetB7_119 (Reshape)   (None, 1, 1, 288)    0           ['EfficientNetB7_118[0][0]']     Y
#
#  EfficientNetB7_120 (Conv2D)    (None, 1, 1, 12)     3468        ['EfficientNetB7_119[0][0]']     Y
#
#  EfficientNetB7_121 (Conv2D)    (None, 1, 1, 288)    3744        ['EfficientNetB7_120[0][0]']     Y
#
#  EfficientNetB7_122 (Multiply)  (None, 56, 56, 288)  0           ['EfficientNetB7_117[0][0]',     Y
#                                                                   'EfficientNetB7_121[0][0]']
#
#  EfficientNetB7_123 (Conv2D)    (None, 56, 56, 48)   13824       ['EfficientNetB7_122[0][0]']     Y
#
#  EfficientNetB7_124 (BatchNorma  (None, 56, 56, 48)  192         ['EfficientNetB7_123[0][0]']     Y
#  lization)
#
#  EfficientNetB7_125 (Dropout)   (None, 56, 56, 48)   0           ['EfficientNetB7_124[0][0]']     Y
#
#  EfficientNetB7_126 (Add)       (None, 56, 56, 48)   0           ['EfficientNetB7_125[0][0]',     Y
#                                                                   'EfficientNetB7_111[0][0]']
#
#  EfficientNetB7_127 (Conv2D)    (None, 56, 56, 288)  13824       ['EfficientNetB7_126[0][0]']     Y
#
#  EfficientNetB7_128 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_127[0][0]']     Y
#  lization)
#
#  EfficientNetB7_129 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_128[0][0]']     Y
#  )
#
#  EfficientNetB7_130 (DepthwiseC  (None, 56, 56, 288)  2592       ['EfficientNetB7_129[0][0]']     Y
#  onv2D)
#
#  EfficientNetB7_131 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_130[0][0]']     Y
#  lization)
#
#  EfficientNetB7_132 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_131[0][0]']     Y
#  )
#
#  EfficientNetB7_133 (GlobalAver  (None, 288)         0           ['EfficientNetB7_132[0][0]']     Y
#  agePooling2D)
#
#  EfficientNetB7_134 (Reshape)   (None, 1, 1, 288)    0           ['EfficientNetB7_133[0][0]']     Y
#
#  EfficientNetB7_135 (Conv2D)    (None, 1, 1, 12)     3468        ['EfficientNetB7_134[0][0]']     Y
#
#  EfficientNetB7_136 (Conv2D)    (None, 1, 1, 288)    3744        ['EfficientNetB7_135[0][0]']     Y
#
#  EfficientNetB7_137 (Multiply)  (None, 56, 56, 288)  0           ['EfficientNetB7_132[0][0]',     Y
#                                                                   'EfficientNetB7_136[0][0]']
#
#  EfficientNetB7_138 (Conv2D)    (None, 56, 56, 48)   13824       ['EfficientNetB7_137[0][0]']     Y
#
#  EfficientNetB7_139 (BatchNorma  (None, 56, 56, 48)  192         ['EfficientNetB7_138[0][0]']     Y
#  lization)
#
#  EfficientNetB7_140 (Dropout)   (None, 56, 56, 48)   0           ['EfficientNetB7_139[0][0]']     Y
#
#  EfficientNetB7_141 (Add)       (None, 56, 56, 48)   0           ['EfficientNetB7_140[0][0]',     Y
#                                                                   'EfficientNetB7_126[0][0]']
#
#  EfficientNetB7_142 (Conv2D)    (None, 56, 56, 288)  13824       ['EfficientNetB7_141[0][0]']     Y
#
#  EfficientNetB7_143 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_142[0][0]']     Y
#  lization)
#
#  EfficientNetB7_144 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_143[0][0]']     Y
#  )
#
#  EfficientNetB7_145 (DepthwiseC  (None, 56, 56, 288)  2592       ['EfficientNetB7_144[0][0]']     Y
#  onv2D)
#
#  EfficientNetB7_146 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_145[0][0]']     Y
#  lization)
#
#  EfficientNetB7_147 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_146[0][0]']     Y
#  )
#
#  EfficientNetB7_148 (GlobalAver  (None, 288)         0           ['EfficientNetB7_147[0][0]']     Y
#  agePooling2D)
#
#  EfficientNetB7_149 (Reshape)   (None, 1, 1, 288)    0           ['EfficientNetB7_148[0][0]']     Y
#
#  EfficientNetB7_150 (Conv2D)    (None, 1, 1, 12)     3468        ['EfficientNetB7_149[0][0]']     Y
#
#  EfficientNetB7_151 (Conv2D)    (None, 1, 1, 288)    3744        ['EfficientNetB7_150[0][0]']     Y
#
#  EfficientNetB7_152 (Multiply)  (None, 56, 56, 288)  0           ['EfficientNetB7_147[0][0]',     Y
#                                                                   'EfficientNetB7_151[0][0]']
#
#  EfficientNetB7_153 (Conv2D)    (None, 56, 56, 48)   13824       ['EfficientNetB7_152[0][0]']     Y
#
#  EfficientNetB7_154 (BatchNorma  (None, 56, 56, 48)  192         ['EfficientNetB7_153[0][0]']     Y
#  lization)
#
#  EfficientNetB7_155 (Dropout)   (None, 56, 56, 48)   0           ['EfficientNetB7_154[0][0]']     Y
#
#  EfficientNetB7_156 (Add)       (None, 56, 56, 48)   0           ['EfficientNetB7_155[0][0]',     Y
#                                                                   'EfficientNetB7_141[0][0]']
#
#  EfficientNetB7_157 (Conv2D)    (None, 56, 56, 288)  13824       ['EfficientNetB7_156[0][0]']     Y
#
#  EfficientNetB7_158 (BatchNorma  (None, 56, 56, 288)  1152       ['EfficientNetB7_157[0][0]']     Y
#  lization)
#
#  EfficientNetB7_159 (Activation  (None, 56, 56, 288)  0          ['EfficientNetB7_158[0][0]']     Y
#  )
#
#  EfficientNetB7_160 (ZeroPaddin  (None, 59, 59, 288)  0          ['EfficientNetB7_159[0][0]']     Y
#  g2D)
#
#  EfficientNetB7_161 (DepthwiseC  (None, 28, 28, 288)  7200       ['EfficientNetB7_160[0][0]']     Y
#  onv2D)
#
#  EfficientNetB7_162 (BatchNorma  (None, 28, 28, 288)  1152       ['EfficientNetB7_161[0][0]']     Y
#  lization)
#
#  EfficientNetB7_163 (Activation  (None, 28, 28, 288)  0          ['EfficientNetB7_162[0][0]']     Y
#  )
#
#  EfficientNetB7_164 (GlobalAver  (None, 288)         0           ['EfficientNetB7_163[0][0]']     Y
# ...
#  DenseNet121_418 (BatchNormaliz  (None, 7, 7, 992)   3968        ['DenseNet121_417[0][0]']        Y
#  ation)
#
#  EfficientNetB7_804 (Conv2D)    (None, 1, 1, 3840)   618240      ['EfficientNetB7_803[0][0]']     Y
#
#  ResNet50_167 (Activation)      (None, 7, 7, 512)    0           ['ResNet50_166[0][0]']           Y
#
#  DenseNet121_419 (Activation)   (None, 7, 7, 992)    0           ['DenseNet121_418[0][0]']        Y
#
#  EfficientNetB7_805 (Multiply)  (None, 7, 7, 3840)   0           ['EfficientNetB7_800[0][0]',     Y
#                                                                   'EfficientNetB7_804[0][0]']
#
#  ResNet50_168 (Conv2D)          (None, 7, 7, 512)    2359808     ['ResNet50_167[0][0]']           Y
#
#  DenseNet121_420 (Conv2D)       (None, 7, 7, 128)    126976      ['DenseNet121_419[0][0]']        Y
#
#  EfficientNetB7_806 (Conv2D)    (None, 7, 7, 640)    2457600     ['EfficientNetB7_805[0][0]']     Y
#
#  ResNet50_169 (BatchNormalizati  (None, 7, 7, 512)   2048        ['ResNet50_168[0][0]']           Y
#  on)
#
#  DenseNet121_421 (BatchNormaliz  (None, 7, 7, 128)   512         ['DenseNet121_420[0][0]']        Y
#  ation)
#
#  EfficientNetB7_807 (BatchNorma  (None, 7, 7, 640)   2560        ['EfficientNetB7_806[0][0]']     Y
#  lization)
#
#  ResNet50_170 (Activation)      (None, 7, 7, 512)    0           ['ResNet50_169[0][0]']           Y
#
#  DenseNet121_422 (Activation)   (None, 7, 7, 128)    0           ['DenseNet121_421[0][0]']        Y
#
#  EfficientNetB7_808 (Dropout)   (None, 7, 7, 640)    0           ['EfficientNetB7_807[0][0]']     Y
#
#  ResNet50_171 (Conv2D)          (None, 7, 7, 2048)   1050624     ['ResNet50_170[0][0]']           Y
#
#  DenseNet121_423 (Conv2D)       (None, 7, 7, 32)     36864       ['DenseNet121_422[0][0]']        Y
#
#  EfficientNetB7_809 (Add)       (None, 7, 7, 640)    0           ['EfficientNetB7_808[0][0]',     Y
#                                                                   'EfficientNetB7_794[0][0]']
#
#  ResNet50_172 (BatchNormalizati  (None, 7, 7, 2048)  8192        ['ResNet50_171[0][0]']           Y
#  on)
#
#  DenseNet121_424 (Concatenate)  (None, 7, 7, 1024)   0           ['DenseNet121_417[0][0]',        Y
#                                                                   'DenseNet121_423[0][0]']
#
#  EfficientNetB7_810 (Conv2D)    (None, 7, 7, 2560)   1638400     ['EfficientNetB7_809[0][0]']     Y
#
#  ResNet50_173 (Add)             (None, 7, 7, 2048)   0           ['ResNet50_164[0][0]',           Y
#                                                                   'ResNet50_172[0][0]']
#
#  DenseNet121_425 (BatchNormaliz  (None, 7, 7, 1024)  4096        ['DenseNet121_424[0][0]']        Y
#  ation)
#
#  EfficientNetB7_811 (BatchNorma  (None, 7, 7, 2560)  10240       ['EfficientNetB7_810[0][0]']     Y
#  lization)
#
#  ResNet50_174 (Activation)      (None, 7, 7, 2048)   0           ['ResNet50_173[0][0]']           Y
#
#  DenseNet121_426 (Activation)   (None, 7, 7, 1024)   0           ['DenseNet121_425[0][0]']        Y
#
#  EfficientNetB7_812 (Activation  (None, 7, 7, 2560)  0           ['EfficientNetB7_811[0][0]']     Y
#  )
#
#  global_average_pooling2d_9 (Gl  (None, 2048)        0           ['ResNet50_174[0][0]']           Y
#  obalAveragePooling2D)
#
#  global_average_pooling2d_10 (G  (None, 1024)        0           ['DenseNet121_426[0][0]']        Y
#  lobalAveragePooling2D)
#
#  global_average_pooling2d_11 (G  (None, 2560)        0           ['EfficientNetB7_812[0][0]']     Y
#  lobalAveragePooling2D)
#
#  dense_33 (Dense)               (None, 1024)         2098176     ['global_average_pooling2d_9[0]  Y
#                                                                  [0]']
#
#  dense_36 (Dense)               (None, 1024)         1049600     ['global_average_pooling2d_10[0  Y
#                                                                  ][0]']
#
#  dense_39 (Dense)               (None, 1024)         2622464     ['global_average_pooling2d_11[0  Y
#                                                                  ][0]']
#
#  dropout_21 (Dropout)           (None, 1024)         0           ['dense_33[0][0]']               Y
#
#  dropout_23 (Dropout)           (None, 1024)         0           ['dense_36[0][0]']               Y
#
#  dropout_25 (Dropout)           (None, 1024)         0           ['dense_39[0][0]']               Y
#
#  batch_normalization_21 (BatchN  (None, 1024)        4096        ['dropout_21[0][0]']             Y
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 1024)        4096        ['dropout_23[0][0]']             Y
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 1024)        4096        ['dropout_25[0][0]']             Y
#  ormalization)
#
#  dense_34 (Dense)               (None, 512)          524800      ['batch_normalization_21[0][0]'  Y
#                                                                  ]
#
#  dense_37 (Dense)               (None, 512)          524800      ['batch_normalization_23[0][0]'  Y
#                                                                  ]
#
#  dense_40 (Dense)               (None, 512)          524800      ['batch_normalization_25[0][0]'  Y
#                                                                  ]
#
#  dropout_22 (Dropout)           (None, 512)          0           ['dense_34[0][0]']               Y
#
#  dropout_24 (Dropout)           (None, 512)          0           ['dense_37[0][0]']               Y
#
#  dropout_26 (Dropout)           (None, 512)          0           ['dense_40[0][0]']               Y
#
#  batch_normalization_22 (BatchN  (None, 512)         2048        ['dropout_22[0][0]']             Y
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 512)         2048        ['dropout_24[0][0]']             Y
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 512)         2048        ['dropout_26[0][0]']             Y
#  ormalization)
#
#  dense_35 (Dense)               (None, 128)          65664       ['batch_normalization_22[0][0]'  Y
#                                                                  ]
#
#  dense_38 (Dense)               (None, 128)          65664       ['batch_normalization_24[0][0]'  Y
#                                                                  ]
#
#  dense_41 (Dense)               (None, 128)          65664       ['batch_normalization_26[0][0]'  Y
#                                                                  ]
#
#  concatenate_3 (Concatenate)    (None, 384)          0           ['dense_35[0][0]',               Y
#                                                                   'dense_38[0][0]',
#                                                                   'dense_41[0][0]']
#
#  dense_42 (Dense)               (None, 64)           24640       ['concatenate_3[0][0]']          Y
#
#  batch_normalization_27 (BatchN  (None, 64)          256         ['dense_42[0][0]']               Y
#  ormalization)
#
#  dense_43 (Dense)               (None, 2)            130         ['batch_normalization_27[0][0]'  Y
#                                                                  ]
#
# =============================================================================================================
# Total params: 102,307,993
# Trainable params: 101,851,154
# Non-trainable params: 456,839
# _____________________________________________________________________________________________________________
# done.

# %% [markdown]
# ### V(T) Beta

# %% [markdown]
# ## Loading the model

# %% [markdown]
# ### Loading the full model

# %%
import efficientnet.tfkeras
# Configuration
PRMC = False
freeze_from_opposite = False
Extra_EXT = ''
freeze_layers = 0  
randomly_frozen_layers = 0 # the Cl
RESET_last_seven = False
freeze_last_seven = False  
# CEC_opt = Adagrad()
# CEC_opt = Yogi()
# CEC_opt = AdaBeliefOptimizer(epsilon=1e-7, rectify=False, weight_decay=1e-3)
CEC_opt = SGD(momentum=0.9, nesterov=False)
# CEC_opt = Adam()
# Main
try:
    if SAVE_TYPE == 'TF':
        model = load_model(f'PAI_model{Extra_EXT}', compile=PRMC)
    else:
        model = load_model(f'PAI_model{Extra_EXT}.h5', compile=PRMC)
except (ImportError, IOError) as e:
    print(f'\033[91mfailed to load the model ERROR:\n{e}')
else:
    print('\033[92mLoading model done.')
    if not PRMC:
        print('Compiling the AI model...\033[0m')
        
        for layer in model.layers:
            layer.trainable = True
        
        # Select random layers to freeze
        frozen_layer_indices = random.sample(range(len(model.layers)), randomly_frozen_layers)
        
        for i, layer in enumerate(model.layers):
            if i in frozen_layer_indices:
                layer.trainable = False
            else:
                if freeze_from_opposite and (i > len(model.layers) - freeze_layers):
                    layer.trainable = False
                elif (not freeze_from_opposite) and i < freeze_layers:
                    layer.trainable = False
                else:
                    layer.trainable = True
        
        for layer in model.layers[-7:]:
            layer.trainable = not freeze_last_seven
        
        if RESET_last_seven:
            for layer in model.layers[-7:]:
                if hasattr(layer, 'kernel_initializer') and hasattr(layer, 'bias_initializer'):
                    weight_initializer = layer.kernel_initializer
                    bias_initializer = layer.bias_initializer

                    old_weights, old_biases = layer.get_weights()

                    layer.set_weights([
                        weight_initializer(shape=old_weights.shape),
                        bias_initializer(shape=len(old_biases))
                    ])
                    
        model.compile(optimizer=CEC_opt, loss='categorical_crossentropy', metrics=['accuracy'])
        model.summary(show_trainable=True, expand_nested=True)
        print('done.')
# Out:
# Loading model done.
# Compiling the AI model...
# Model: "model"
# _____________________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to                     Trainable
# =============================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []                               Y
#                                 )]
#
#  stem_conv (Conv2D)             (None, 112, 112, 64  1728        ['input_2[0][0]']                Y
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 64  256         ['stem_conv[0][0]']              Y
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 64  0           ['stem_bn[0][0]']                Y
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 112, 112, 64  576        ['stem_activation[0][0]']        Y
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 112, 112, 64  256        ['block1a_dwconv[0][0]']         Y
#  )                              )
#
#  block1a_activation (Activation  (None, 112, 112, 64  0          ['block1a_bn[0][0]']             Y
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 64)          0           ['block1a_activation[0][0]']     Y
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 64)     0           ['block1a_se_squeeze[0][0]']     Y
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 16)     1040        ['block1a_se_reshape[0][0]']     Y
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 64)     1088        ['block1a_se_reduce[0][0]']      Y
#
#  block1a_se_excite (Multiply)   (None, 112, 112, 64  0           ['block1a_activation[0][0]',     Y
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 32  2048        ['block1a_se_excite[0][0]']      Y
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 32  128        ['block1a_project_conv[0][0]']   Y
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 112, 112, 32  288        ['block1a_project_bn[0][0]']     Y
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 112, 112, 32  128        ['block1b_dwconv[0][0]']         Y
#  )                              )
#
#  block1b_activation (Activation  (None, 112, 112, 32  0          ['block1b_bn[0][0]']             Y
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 32)          0           ['block1b_activation[0][0]']     Y
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1b_se_squeeze[0][0]']     Y
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1b_se_reshape[0][0]']     Y
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1b_se_reduce[0][0]']      Y
#
#  block1b_se_excite (Multiply)   (None, 112, 112, 32  0           ['block1b_activation[0][0]',     Y
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 112, 112, 32  1024        ['block1b_se_excite[0][0]']      Y
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 112, 112, 32  128        ['block1b_project_conv[0][0]']   Y
#  lization)                      )
#
#  block1b_drop (FixedDropout)    (None, 112, 112, 32  0           ['block1b_project_bn[0][0]']     Y
#                                 )
#
#  block1b_add (Add)              (None, 112, 112, 32  0           ['block1b_drop[0][0]',           Y
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block1c_dwconv (DepthwiseConv2  (None, 112, 112, 32  288        ['block1b_add[0][0]']            Y
#  D)                             )
#
#  block1c_bn (BatchNormalization  (None, 112, 112, 32  128        ['block1c_dwconv[0][0]']         Y
#  )                              )
#
#  block1c_activation (Activation  (None, 112, 112, 32  0          ['block1c_bn[0][0]']             Y
#  )                              )
#
#  block1c_se_squeeze (GlobalAver  (None, 32)          0           ['block1c_activation[0][0]']     Y
#  agePooling2D)
#
#  block1c_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1c_se_squeeze[0][0]']     Y
#
#  block1c_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1c_se_reshape[0][0]']     Y
#
#  block1c_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1c_se_reduce[0][0]']      Y
#
#  block1c_se_excite (Multiply)   (None, 112, 112, 32  0           ['block1c_activation[0][0]',     Y
#                                 )                                 'block1c_se_expand[0][0]']
#
#  block1c_project_conv (Conv2D)  (None, 112, 112, 32  1024        ['block1c_se_excite[0][0]']      Y
#                                 )
#
#  block1c_project_bn (BatchNorma  (None, 112, 112, 32  128        ['block1c_project_conv[0][0]']   Y
#  lization)                      )
#
#  block1c_drop (FixedDropout)    (None, 112, 112, 32  0           ['block1c_project_bn[0][0]']     Y
#                                 )
#
#  block1c_add (Add)              (None, 112, 112, 32  0           ['block1c_drop[0][0]',           Y
#                                 )                                 'block1b_add[0][0]']
#
#  block1d_dwconv (DepthwiseConv2  (None, 112, 112, 32  288        ['block1c_add[0][0]']            Y
#  D)                             )
#
#  block1d_bn (BatchNormalization  (None, 112, 112, 32  128        ['block1d_dwconv[0][0]']         Y
#  )                              )
#
#  block1d_activation (Activation  (None, 112, 112, 32  0          ['block1d_bn[0][0]']             Y
#  )                              )
#
#  block1d_se_squeeze (GlobalAver  (None, 32)          0           ['block1d_activation[0][0]']     Y
#  agePooling2D)
#
#  block1d_se_reshape (Reshape)   (None, 1, 1, 32)     0           ['block1d_se_squeeze[0][0]']     Y
#
#  block1d_se_reduce (Conv2D)     (None, 1, 1, 8)      264         ['block1d_se_reshape[0][0]']     Y
#
#  block1d_se_expand (Conv2D)     (None, 1, 1, 32)     288         ['block1d_se_reduce[0][0]']      Y
#
#  block1d_se_excite (Multiply)   (None, 112, 112, 32  0           ['block1d_activation[0][0]',     Y
#                                 )                                 'block1d_se_expand[0][0]']
#
#  block1d_project_conv (Conv2D)  (None, 112, 112, 32  1024        ['block1d_se_excite[0][0]']      Y
#                                 )
#
#  block1d_project_bn (BatchNorma  (None, 112, 112, 32  128        ['block1d_project_conv[0][0]']   Y
#  lization)                      )
#
#  block1d_drop (FixedDropout)    (None, 112, 112, 32  0           ['block1d_project_bn[0][0]']     Y
#                                 )
#
#  block1d_add (Add)              (None, 112, 112, 32  0           ['block1d_drop[0][0]',           Y
#                                 )                                 'block1c_add[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 112, 112, 19  6144        ['block1d_add[0][0]']            Y
#                                 2)
#
#  block2a_expand_bn (BatchNormal  (None, 112, 112, 19  768        ['block2a_expand_conv[0][0]']    Y
#  ization)                       2)
#
#  block2a_expand_activation (Act  (None, 112, 112, 19  0          ['block2a_expand_bn[0][0]']      Y
#  ivation)                       2)
#
#  block2a_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2a_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block2a_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2a_dwconv[0][0]']         Y
#  )
#
#  block2a_activation (Activation  (None, 56, 56, 192)  0          ['block2a_bn[0][0]']             Y
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 192)         0           ['block2a_activation[0][0]']     Y
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2a_se_squeeze[0][0]']     Y
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2a_se_reshape[0][0]']     Y
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2a_se_reduce[0][0]']      Y
#
#  block2a_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2a_activation[0][0]',     Y
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 48)   9216        ['block2a_se_excite[0][0]']      Y
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2a_project_conv[0][0]']   Y
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 288)  13824       ['block2a_project_bn[0][0]']     Y
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 288)  1152       ['block2b_expand_conv[0][0]']    Y
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 288)  0          ['block2b_expand_bn[0][0]']      Y
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 56, 56, 288)  2592       ['block2b_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block2b_bn (BatchNormalization  (None, 56, 56, 288)  1152       ['block2b_dwconv[0][0]']         Y
#  )
#
#  block2b_activation (Activation  (None, 56, 56, 288)  0          ['block2b_bn[0][0]']             Y
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 288)         0           ['block2b_activation[0][0]']     Y
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2b_se_squeeze[0][0]']     Y
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2b_se_reshape[0][0]']     Y
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2b_se_reduce[0][0]']      Y
#
#  block2b_se_excite (Multiply)   (None, 56, 56, 288)  0           ['block2b_activation[0][0]',     Y
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 48)   13824       ['block2b_se_excite[0][0]']      Y
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2b_project_conv[0][0]']   Y
#  lization)
#
#  block2b_drop (FixedDropout)    (None, 56, 56, 48)   0           ['block2b_project_bn[0][0]']     Y
#
#  block2b_add (Add)              (None, 56, 56, 48)   0           ['block2b_drop[0][0]',           Y
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 56, 56, 288)  13824       ['block2b_add[0][0]']            Y
#
#  block2c_expand_bn (BatchNormal  (None, 56, 56, 288)  1152       ['block2c_expand_conv[0][0]']    Y
#  ization)
#
#  block2c_expand_activation (Act  (None, 56, 56, 288)  0          ['block2c_expand_bn[0][0]']      Y
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 56, 56, 288)  2592       ['block2c_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block2c_bn (BatchNormalization  (None, 56, 56, 288)  1152       ['block2c_dwconv[0][0]']         Y
#  )
#
#  block2c_activation (Activation  (None, 56, 56, 288)  0          ['block2c_bn[0][0]']             Y
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 288)         0           ['block2c_activation[0][0]']     Y
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2c_se_squeeze[0][0]']     Y
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2c_se_reshape[0][0]']     Y
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2c_se_reduce[0][0]']      Y
#
#  block2c_se_excite (Multiply)   (None, 56, 56, 288)  0           ['block2c_activation[0][0]',     Y
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 56, 56, 48)   13824       ['block2c_se_excite[0][0]']      Y
#
#  block2c_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2c_project_conv[0][0]']   Y
#  lization)
#
#  block2c_drop (FixedDropout)    (None, 56, 56, 48)   0           ['block2c_project_bn[0][0]']     Y
#
#  block2c_add (Add)              (None, 56, 56, 48)   0           ['block2c_drop[0][0]',           Y
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 56, 56, 288)  13824       ['block2c_add[0][0]']            Y
#
#  block2d_expand_bn (BatchNormal  (None, 56, 56, 288)  1152       ['block2d_expand_conv[0][0]']    Y
#  ization)
#
#  block2d_expand_activation (Act  (None, 56, 56, 288)  0          ['block2d_expand_bn[0][0]']      Y
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 56, 56, 288)  2592       ['block2d_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block2d_bn (BatchNormalization  (None, 56, 56, 288)  1152       ['block2d_dwconv[0][0]']         Y
#  )
#
#  block2d_activation (Activation  (None, 56, 56, 288)  0          ['block2d_bn[0][0]']             Y
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 288)         0           ['block2d_activation[0][0]']     Y
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2d_se_squeeze[0][0]']     Y
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2d_se_reshape[0][0]']     Y
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2d_se_reduce[0][0]']      Y
#
#  block2d_se_excite (Multiply)   (None, 56, 56, 288)  0           ['block2d_activation[0][0]',     Y
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 56, 56, 48)   13824       ['block2d_se_excite[0][0]']      Y
#
#  block2d_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2d_project_conv[0][0]']   Y
#  lization)
#
#  block2d_drop (FixedDropout)    (None, 56, 56, 48)   0           ['block2d_project_bn[0][0]']     Y
#
#  block2d_add (Add)              (None, 56, 56, 48)   0           ['block2d_drop[0][0]',           Y
#                                                                   'block2c_add[0][0]']
#
#  block2e_expand_conv (Conv2D)   (None, 56, 56, 288)  13824       ['block2d_add[0][0]']            Y
#
#  block2e_expand_bn (BatchNormal  (None, 56, 56, 288)  1152       ['block2e_expand_conv[0][0]']    Y
#  ization)
#
#  block2e_expand_activation (Act  (None, 56, 56, 288)  0          ['block2e_expand_bn[0][0]']      Y
#  ivation)
#
#  block2e_dwconv (DepthwiseConv2  (None, 56, 56, 288)  2592       ['block2e_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block2e_bn (BatchNormalization  (None, 56, 56, 288)  1152       ['block2e_dwconv[0][0]']         Y
#  )
#
#  block2e_activation (Activation  (None, 56, 56, 288)  0          ['block2e_bn[0][0]']             Y
#  )
#
#  block2e_se_squeeze (GlobalAver  (None, 288)         0           ['block2e_activation[0][0]']     Y
#  agePooling2D)
#
#  block2e_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2e_se_squeeze[0][0]']     Y
#
#  block2e_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2e_se_reshape[0][0]']     Y
#
#  block2e_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2e_se_reduce[0][0]']      Y
#
#  block2e_se_excite (Multiply)   (None, 56, 56, 288)  0           ['block2e_activation[0][0]',     Y
#                                                                   'block2e_se_expand[0][0]']
#
#  block2e_project_conv (Conv2D)  (None, 56, 56, 48)   13824       ['block2e_se_excite[0][0]']      Y
#
#  block2e_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2e_project_conv[0][0]']   Y
#  lization)
#
#  block2e_drop (FixedDropout)    (None, 56, 56, 48)   0           ['block2e_project_bn[0][0]']     Y
#
#  block2e_add (Add)              (None, 56, 56, 48)   0           ['block2e_drop[0][0]',           Y
#                                                                   'block2d_add[0][0]']
#
#  block2f_expand_conv (Conv2D)   (None, 56, 56, 288)  13824       ['block2e_add[0][0]']            Y
#
#  block2f_expand_bn (BatchNormal  (None, 56, 56, 288)  1152       ['block2f_expand_conv[0][0]']    Y
#  ization)
#
#  block2f_expand_activation (Act  (None, 56, 56, 288)  0          ['block2f_expand_bn[0][0]']      Y
#  ivation)
#
#  block2f_dwconv (DepthwiseConv2  (None, 56, 56, 288)  2592       ['block2f_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block2f_bn (BatchNormalization  (None, 56, 56, 288)  1152       ['block2f_dwconv[0][0]']         Y
#  )
#
#  block2f_activation (Activation  (None, 56, 56, 288)  0          ['block2f_bn[0][0]']             Y
#  )
#
#  block2f_se_squeeze (GlobalAver  (None, 288)         0           ['block2f_activation[0][0]']     Y
#  agePooling2D)
#
#  block2f_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2f_se_squeeze[0][0]']     Y
#
#  block2f_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2f_se_reshape[0][0]']     Y
#
#  block2f_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2f_se_reduce[0][0]']      Y
#
#  block2f_se_excite (Multiply)   (None, 56, 56, 288)  0           ['block2f_activation[0][0]',     Y
#                                                                   'block2f_se_expand[0][0]']
#
#  block2f_project_conv (Conv2D)  (None, 56, 56, 48)   13824       ['block2f_se_excite[0][0]']      Y
#
#  block2f_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2f_project_conv[0][0]']   Y
#  lization)
#
#  block2f_drop (FixedDropout)    (None, 56, 56, 48)   0           ['block2f_project_bn[0][0]']     Y
#
#  block2f_add (Add)              (None, 56, 56, 48)   0           ['block2f_drop[0][0]',           Y
#                                                                   'block2e_add[0][0]']
#
#  block2g_expand_conv (Conv2D)   (None, 56, 56, 288)  13824       ['block2f_add[0][0]']            Y
#
#  block2g_expand_bn (BatchNormal  (None, 56, 56, 288)  1152       ['block2g_expand_conv[0][0]']    Y
#  ization)
#
#  block2g_expand_activation (Act  (None, 56, 56, 288)  0          ['block2g_expand_bn[0][0]']      Y
#  ivation)
#
#  block2g_dwconv (DepthwiseConv2  (None, 56, 56, 288)  2592       ['block2g_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block2g_bn (BatchNormalization  (None, 56, 56, 288)  1152       ['block2g_dwconv[0][0]']         Y
#  )
#
#  block2g_activation (Activation  (None, 56, 56, 288)  0          ['block2g_bn[0][0]']             Y
#  )
#
#  block2g_se_squeeze (GlobalAver  (None, 288)         0           ['block2g_activation[0][0]']     Y
#  agePooling2D)
#
#  block2g_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block2g_se_squeeze[0][0]']     Y
#
#  block2g_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block2g_se_reshape[0][0]']     Y
#
#  block2g_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block2g_se_reduce[0][0]']      Y
#
#  block2g_se_excite (Multiply)   (None, 56, 56, 288)  0           ['block2g_activation[0][0]',     Y
#                                                                   'block2g_se_expand[0][0]']
#
#  block2g_project_conv (Conv2D)  (None, 56, 56, 48)   13824       ['block2g_se_excite[0][0]']      Y
#
#  block2g_project_bn (BatchNorma  (None, 56, 56, 48)  192         ['block2g_project_conv[0][0]']   Y
#  lization)
#
#  block2g_drop (FixedDropout)    (None, 56, 56, 48)   0           ['block2g_project_bn[0][0]']     Y
#
#  block2g_add (Add)              (None, 56, 56, 48)   0           ['block2g_drop[0][0]',           Y
#                                                                   'block2f_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 56, 56, 288)  13824       ['block2g_add[0][0]']            Y
#
#  block3a_expand_bn (BatchNormal  (None, 56, 56, 288)  1152       ['block3a_expand_conv[0][0]']    Y
#  ization)
#
#  block3a_expand_activation (Act  (None, 56, 56, 288)  0          ['block3a_expand_bn[0][0]']      Y
#  ivation)
#
#  block3a_dwconv (DepthwiseConv2  (None, 28, 28, 288)  7200       ['block3a_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block3a_bn (BatchNormalization  (None, 28, 28, 288)  1152       ['block3a_dwconv[0][0]']         Y
#  )
#
#  block3a_activation (Activation  (None, 28, 28, 288)  0          ['block3a_bn[0][0]']             Y
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 288)         0           ['block3a_activation[0][0]']     Y
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 288)    0           ['block3a_se_squeeze[0][0]']     Y
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 12)     3468        ['block3a_se_reshape[0][0]']     Y
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 288)    3744        ['block3a_se_reduce[0][0]']      Y
# ...
#
#  block7b_expand_bn (BatchNormal  (None, 7, 7, 3840)  15360       ['block7b_expand_conv[0][0]']    Y
#  ization)
#
#  block7b_expand_activation (Act  (None, 7, 7, 3840)  0           ['block7b_expand_bn[0][0]']      Y
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 7, 7, 3840)  34560       ['block7b_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block7b_bn (BatchNormalization  (None, 7, 7, 3840)  15360       ['block7b_dwconv[0][0]']         Y
#  )
#
#  block7b_activation (Activation  (None, 7, 7, 3840)  0           ['block7b_bn[0][0]']             Y
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 3840)        0           ['block7b_activation[0][0]']     Y
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7b_se_squeeze[0][0]']     Y
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7b_se_reshape[0][0]']     Y
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7b_se_reduce[0][0]']      Y
#
#  block7b_se_excite (Multiply)   (None, 7, 7, 3840)   0           ['block7b_activation[0][0]',     Y
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 7, 7, 640)    2457600     ['block7b_se_excite[0][0]']      Y
#
#  block7b_project_bn (BatchNorma  (None, 7, 7, 640)   2560        ['block7b_project_conv[0][0]']   Y
#  lization)
#
#  block7b_drop (FixedDropout)    (None, 7, 7, 640)    0           ['block7b_project_bn[0][0]']     Y
#
#  block7b_add (Add)              (None, 7, 7, 640)    0           ['block7b_drop[0][0]',           Y
#                                                                   'block7a_project_bn[0][0]']
#
#  block7c_expand_conv (Conv2D)   (None, 7, 7, 3840)   2457600     ['block7b_add[0][0]']            Y
#
#  block7c_expand_bn (BatchNormal  (None, 7, 7, 3840)  15360       ['block7c_expand_conv[0][0]']    Y
#  ization)
#
#  block7c_expand_activation (Act  (None, 7, 7, 3840)  0           ['block7c_expand_bn[0][0]']      Y
#  ivation)
#
#  block7c_dwconv (DepthwiseConv2  (None, 7, 7, 3840)  34560       ['block7c_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block7c_bn (BatchNormalization  (None, 7, 7, 3840)  15360       ['block7c_dwconv[0][0]']         Y
#  )
#
#  block7c_activation (Activation  (None, 7, 7, 3840)  0           ['block7c_bn[0][0]']             Y
#  )
#
#  block7c_se_squeeze (GlobalAver  (None, 3840)        0           ['block7c_activation[0][0]']     Y
#  agePooling2D)
#
#  block7c_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7c_se_squeeze[0][0]']     Y
#
#  block7c_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7c_se_reshape[0][0]']     Y
#
#  block7c_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7c_se_reduce[0][0]']      Y
#
#  block7c_se_excite (Multiply)   (None, 7, 7, 3840)   0           ['block7c_activation[0][0]',     Y
#                                                                   'block7c_se_expand[0][0]']
#
#  block7c_project_conv (Conv2D)  (None, 7, 7, 640)    2457600     ['block7c_se_excite[0][0]']      Y
#
#  block7c_project_bn (BatchNorma  (None, 7, 7, 640)   2560        ['block7c_project_conv[0][0]']   Y
#  lization)
#
#  block7c_drop (FixedDropout)    (None, 7, 7, 640)    0           ['block7c_project_bn[0][0]']     Y
#
#  block7c_add (Add)              (None, 7, 7, 640)    0           ['block7c_drop[0][0]',           Y
#                                                                   'block7b_add[0][0]']
#
#  block7d_expand_conv (Conv2D)   (None, 7, 7, 3840)   2457600     ['block7c_add[0][0]']            Y
#
#  block7d_expand_bn (BatchNormal  (None, 7, 7, 3840)  15360       ['block7d_expand_conv[0][0]']    Y
#  ization)
#
#  block7d_expand_activation (Act  (None, 7, 7, 3840)  0           ['block7d_expand_bn[0][0]']      Y
#  ivation)
#
#  block7d_dwconv (DepthwiseConv2  (None, 7, 7, 3840)  34560       ['block7d_expand_activation[0][  Y
#  D)                                                              0]']
#
#  block7d_bn (BatchNormalization  (None, 7, 7, 3840)  15360       ['block7d_dwconv[0][0]']         Y
#  )
#
#  block7d_activation (Activation  (None, 7, 7, 3840)  0           ['block7d_bn[0][0]']             Y
#  )
#
#  block7d_se_squeeze (GlobalAver  (None, 3840)        0           ['block7d_activation[0][0]']     Y
#  agePooling2D)
#
#  block7d_se_reshape (Reshape)   (None, 1, 1, 3840)   0           ['block7d_se_squeeze[0][0]']     Y
#
#  block7d_se_reduce (Conv2D)     (None, 1, 1, 160)    614560      ['block7d_se_reshape[0][0]']     Y
#
#  block7d_se_expand (Conv2D)     (None, 1, 1, 3840)   618240      ['block7d_se_reduce[0][0]']      Y
#
#  block7d_se_excite (Multiply)   (None, 7, 7, 3840)   0           ['block7d_activation[0][0]',     Y
#                                                                   'block7d_se_expand[0][0]']
#
#  block7d_project_conv (Conv2D)  (None, 7, 7, 640)    2457600     ['block7d_se_excite[0][0]']      Y
#
#  block7d_project_bn (BatchNorma  (None, 7, 7, 640)   2560        ['block7d_project_conv[0][0]']   Y
#  lization)
#
#  block7d_drop (FixedDropout)    (None, 7, 7, 640)    0           ['block7d_project_bn[0][0]']     Y
#
#  block7d_add (Add)              (None, 7, 7, 640)    0           ['block7d_drop[0][0]',           Y
#                                                                   'block7c_add[0][0]']
#
#  top_conv (Conv2D)              (None, 7, 7, 2560)   1638400     ['block7d_add[0][0]']            Y
#
#  top_bn (BatchNormalization)    (None, 7, 7, 2560)   10240       ['top_conv[0][0]']               Y
#
#  top_activation (Activation)    (None, 7, 7, 2560)   0           ['top_bn[0][0]']                 Y
#
#  global_average_pooling2d (Glob  (None, 2560)        0           ['top_activation[0][0]']         Y
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 2048)         5244928     ['global_average_pooling2d[0][0  Y
#                                                                  ]']
#
#  dropout (Dropout)              (None, 2048)         0           ['dense[0][0]']                  Y
#
#  batch_normalization (BatchNorm  (None, 2048)        8192        ['dropout[0][0]']                Y
#  alization)
#
#  dense_1 (Dense)                (None, 512)          1049088     ['batch_normalization[0][0]']    Y
#
#  batch_normalization_1 (BatchNo  (None, 512)         2048        ['dense_1[0][0]']                Y
#  rmalization)
#
#  dense_2 (Dense)                (None, 128)          65664       ['batch_normalization_1[0][0]']  Y
#
#  dense_3 (Dense)                (None, 2)            258         ['dense_2[0][0]']                Y
#
# =============================================================================================================
# Total params: 70,467,858
# Trainable params: 70,152,018
# Non-trainable params: 315,840
# _____________________________________________________________________________________________________________
# done.

# %% [markdown]
# ### Loading model weights

# %%
model.load_weights('PAI_model_weights.h5')
print('done.')
# Out:
# done.

# %% [markdown]
# ## Training

# %%
import gc
# Garbage Collection (memory)
gc.collect()
#other
tf.config.optimizer.set_jit(False)
#conf 
WTD_augmentation = True
Conf_batch_size = 8 # 16
Learning_rate_conf = 1
#TensorBoard conf
TensorBoard_UF = 1 # 1 for Slow 2 for fast (very slow tarining)
# Learning rate configuration
Learning_rate_conf_SET2C = 3 # 1 for SGD (higher lr) and 2 for Adam and... for (lower lr) 3 for normal
# First time
if Learning_rate_conf == 1:
    learning_rate_start = 4e-03
    learning_rate_max = 1e-02
    learning_rate_min = 6e-04
    learning_rate_rampup_epochs = 5
    learning_rate_sustain_epochs = 3
    learning_rate_exp_decay = .38
    #TEMP
    # learning_rate_start = 8e-04
    # learning_rate_max = 1e-03
    # learning_rate_min = 6e-04
    # learning_rate_rampup_epochs = 5
    # learning_rate_sustain_epochs = 3
    # learning_rate_exp_decay = .38
# 2th time
if Learning_rate_conf == 2:
    if Learning_rate_conf_SET2C == 1:
        learning_rate_start = 6e-04
        learning_rate_max = 6e-04
        learning_rate_min = 6e-04
        learning_rate_rampup_epochs = 0
        learning_rate_sustain_epochs = 0
        learning_rate_exp_decay = .1
        
    elif Learning_rate_conf_SET2C == 2:
        learning_rate_start = 4e-07
        learning_rate_max = 4e-07
        learning_rate_min = 4e-07
        learning_rate_rampup_epochs = 0
        learning_rate_sustain_epochs = 0
        learning_rate_exp_decay = .1 
        
    elif Learning_rate_conf_SET2C == 3:
        learning_rate_start = 8e-06
        learning_rate_max = 8e-06
        learning_rate_min = 8e-06
        learning_rate_rampup_epochs = 0
        learning_rate_sustain_epochs = 0
        learning_rate_exp_decay = .1
# Function to build learning rate schedule
def build_learning_rate_fn(lr_start=learning_rate_start,
                           lr_max=learning_rate_max,
                           lr_min=learning_rate_min,
                           lr_rampup_epochs=learning_rate_rampup_epochs,
                           lr_sustain_epochs=learning_rate_sustain_epochs,
                           lr_exp_decay=learning_rate_exp_decay):    
    lr_max = lr_max * tf.distribute.get_strategy().num_replicas_in_sync
    def learning_rate_fn(epoch):
        if epoch < lr_rampup_epochs:
            lr = (lr_max - lr_start) / lr_rampup_epochs * epoch + lr_start
        elif epoch < lr_rampup_epochs + lr_sustain_epochs:
            lr = lr_max
        else:
            lr = (lr_max - lr_min) *\
                 lr_exp_decay**(epoch - lr_rampup_epochs - lr_sustain_epochs) + lr_min
        return lr
    return learning_rate_fn
if WTD_augmentation:
    print_Color('Using WTD_augmentation...', ['yellow'])
    def TF_add_image_grain(image, intensity = 0.01):
        # Generate random noise array in the range [0, 1]
        noise = tf.random.uniform(shape=tf.shape(image), minval=0, maxval=1, dtype=tf.float32)

        # Scale the noise array
        scaled_noise = noise * intensity
        
        # Add the noise to the image
        noisy_image = tf.math.add(image, scaled_noise)

        # Ensure the noisy image does not exceed 1
        noisy_image = tf.clip_by_value(noisy_image, 0.0, 1.0)

        return noisy_image
    # Function to augment images
    def augment_images(image, label):
        image = tf.image.random_flip_left_right(image)
        image = tf.image.random_flip_up_down(image)
        image = tf.image.random_contrast(image, 0.2, 1.8)
        image = tf.image.random_brightness(image, max_delta=0.3)
        # Random intensity between 0 and 0.04
        intensity = random.uniform(0, 0.04)
        image = TF_add_image_grain(image, intensity=intensity)
        # Add random rotation
        # image = tf.image.rot90(image, k=random.randint(0, 3)) 
        return image, label

    # Create TensorFlow dataset
    AUTO = tf.data.experimental.AUTOTUNE
    train_dataset = (
        tf.data.Dataset.from_tensor_slices((x_train, y_train))
        .map(augment_images, num_parallel_calls=AUTO)
        .repeat()
        .shuffle(256)
        .batch(Conf_batch_size)
        .prefetch(AUTO)
    )

    # Calculate steps per epoch
    steps_per_epoch_train = len(x_train) // Conf_batch_size

# Set up callbacks
learning_rate_fn = build_learning_rate_fn()
learning_rate_schedule = LearningRateScheduler(learning_rate_fn, verbose=1)
checkpoint_BVAC = ModelCheckpoint('models\\Temp\\bestVAC_model', monitor='val_accuracy', mode='max', save_best_only=True, verbose=1)
checkpoint_BVL = ModelCheckpoint('models\\Temp\\bestVL_model', monitor='val_loss', mode='min', save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_accuracy', patience=8, verbose=1, restore_best_weights=True)
log_dir = 'logs/fit/' + datetime.datetime.now().strftime('y%Y_m%m_d%d-h%H_m%M_s%S')
TensorBoard_update_freq = 'batch' if TensorBoard_UF == 2 else 'epoch'
tensorboard_callback = TensorBoard(log_dir=log_dir, write_images=True, histogram_freq=1, update_freq=TensorBoard_update_freq)

# Train the model
print('Log dir:', log_dir)
#MInfo
print("Input Shape:", model.input_shape)
print("Output Shape:", model.output_shape)
print("Loss Function:", model.loss)
print('Training the model...\n')
if WTD_augmentation:
    history = model.fit(train_dataset,
                        epochs=256,
                        steps_per_epoch=steps_per_epoch_train,
                        batch_size=Conf_batch_size,
                        validation_data=(x_test, y_test),
                        verbose='auto',
                        callbacks=[early_stopping,
                                tensorboard_callback,
                                learning_rate_schedule,
                                checkpoint_BVAC,
                                checkpoint_BVL])
else:
    history = model.fit(x_train,
                        y_train,
                        epochs=256,
                        batch_size=Conf_batch_size,
                        validation_data=(x_test, y_test),
                        verbose='auto',
                        callbacks=[early_stopping,
                                tensorboard_callback,
                                learning_rate_schedule,
                                checkpoint_BVAC,
                                checkpoint_BVL])
print('Training done.\n')
# Out:
# Using WTD_augmentation...
# Log dir: logs/fit/y2023_m10_d30-h18_m49_s40
# Input Shape: (None, 224, 224, 3)
# Output Shape: (None, 2)
# Loss Function: categorical_crossentropy
# Training the model...
#
#
# Epoch 1: LearningRateScheduler setting learning rate to 0.0008.
# Epoch 1/256
# 1304/1304 [==============================] - ETA: 0s - loss: 25.8911 - accuracy: 0.7403
# Epoch 1: val_accuracy improved from -inf to 0.63462, saving model to models\Temp\bestVAC_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 446). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models\Temp\bestVAC_model\assets
# INFO:tensorflow:Assets written to: models\Temp\bestVAC_model\assets
# Epoch 1: val_loss improved from inf to 15.07889, saving model to models\Temp\bestVL_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 446). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models\Temp\bestVL_model\assets
# INFO:tensorflow:Assets written to: models\Temp\bestVL_model\assets
# 1304/1304 [==============================] - 580s 444ms/step - loss: 25.8911 - accuracy: 0.7403 - val_loss: 15.0789 - val_accuracy: 0.6346 - lr: 8.0000e-04
#
# Epoch 2: LearningRateScheduler setting learning rate to 0.00084.
# Epoch 2/256
# 1304/1304 [==============================] - ETA: 0s - loss: 10.4421 - accuracy: 0.7438
# Epoch 2: val_accuracy did not improve from 0.63462
#
# Epoch 2: val_loss improved from 15.07889 to 7.38799, saving model to models\Temp\bestVL_model
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 446). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: models\Temp\bestVL_model\assets
# INFO:tensorflow:Assets written to: models\Temp\bestVL_model\assets
# 1304/1304 [==============================] - 491s 377ms/step - loss: 10.4421 - accuracy: 0.7438 - val_loss: 7.3880 - val_accuracy: 0.6314 - lr: 8.4000e-04
#
# Epoch 3: LearningRateScheduler setting learning rate to 0.00088.
# Epoch 3/256
# 1253/1304 [===========================>..] - ETA: 13s - loss: 5.7496 - accuracy: 0.7465

# %% [markdown]
# ## Saving model weights

# %%
Extra_EXT = '_T'
# Save the weights
print('Saving weights...')
model.save_weights(f'PAI_model_weights{Extra_EXT}.h5')
print('Saving full model...')
if SAVE_TYPE == 'TF':
    print('Saving full model tf format...')
    model.save(f'PAI_model{Extra_EXT}', save_format='tf')
else:
    try:
        model.save(f'PAI_model{Extra_EXT}.h5')
    except ValueError:
        print('failed to save in .h5 format!')
        print('Saving full model in tf format...')
        model.save('PAI_model', save_format='tf')
# Out:
# Saving weights...
# Saving full model...

# %% [markdown]
# ## Garbage Collection (memory)

# %%
import gc
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Analyse model Training performance

# %%
try:
    #loss
    plt.plot(history.history['loss'], label='loss')
    try:
        plt.plot(history.history['val_loss'], label='val_loss', color='orange')
    except (ValueError, NameError):
        print('\033[91mfailed to load val_loss.')
    plt.title('Model Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.show()
    #acc
    plt.plot(history.history['accuracy'], label='accuracy')
    try:
        plt.plot(history.history['val_accuracy'], label='val_accuracy', color='orange')
    except (ValueError, NameError):
        print('\033[91mfailed to load val_accuracy.')
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.show()
except (ValueError, NameError):
    print('\033[91mfailed to load model history.')

# %% [markdown]
# ## Analyse model Predicting performance

# %% [markdown]
# ### Gradcam heatmap

# %% [markdown]
# #### V2

# %%
def compute_heatmap(model, img_array, conv_layer_name, pred_index):
    """
    Helper function to compute the heatmap for a given convolutional layer.
    """
    grad_model = tf.keras.models.Model(
        [model.inputs], 
        [model.get_layer(conv_layer_name).output, model.output]
    )

    with tf.GradientTape() as tape:
        conv_layer_output, preds = grad_model(img_array)
        class_channel = preds[:, pred_index]

    grads = tape.gradient(class_channel, conv_layer_output)
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    conv_layer_output = conv_layer_output[0]
    heatmap = conv_layer_output @ pooled_grads[..., tf.newaxis]
    heatmap = tf.squeeze(heatmap)
    heatmap = tf.maximum(heatmap, 0) / tf.math.reduce_max(heatmap)
    return heatmap

def make_gradcam_heatmap(img_array, model, last_conv_layer_name, second_last_conv_layer_name=None, pred_index=None, threshold=0, sensitivity_map=1.0):
    """
    Function to compute the Grad-CAM heatmap for a specific class, given an input image.
    """
    if pred_index is None:
        preds = model.predict(img_array)
        pred_index = tf.argmax(preds[0])

    # Compute heatmap for the last convolutional layer
    heatmap = compute_heatmap(model, img_array, last_conv_layer_name, pred_index)
    
    # Apply threshold and adjust sensitivity
    heatmap = np.where(heatmap > threshold, heatmap, 0)
    heatmap = heatmap ** sensitivity_map

    if second_last_conv_layer_name is not None:
        # Compute heatmap for the second last convolutional layer
        heatmap_second = compute_heatmap(model, img_array, second_last_conv_layer_name, pred_index)
        
        # Apply threshold and adjust sensitivity
        heatmap_second = np.where(heatmap_second > threshold, heatmap_second, 0)
        heatmap_second = heatmap_second ** sensitivity_map
        
        # Average the two heatmaps
        heatmap = (heatmap + heatmap_second) / 2.0
    
    return heatmap

# %% [markdown]
# ### Main test

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
from scipy.stats import binom
from tqdm import tqdm
import efficientnet.tfkeras
import cv2

import gc
# Garbage Collection (memory)
gc.collect()

Extra_EXT = ''
prob_L = 0.9995
tick_spacing = 5
Train_data_test = False
if SAVE_TYPE == 'TF':
    # Load the pre-trained model
    model = load_model('PAI_model')
else:
    # Load the pre-trained model
    model = load_model(f'PAI_model{Extra_EXT}.h5')

# Ensure the model's input_shape matches your data
assert model.input_shape[1:] == (img_res[0], img_res[1], img_res[2]), 'Models input shape doesnt match data.'

# Make predictions on validation data
val_predictions = model.predict(x_val)
val_predictions = np.argmax(val_predictions, axis=1)

# Make predictions on Train data
if Train_data_test:
    Train_predictions = model.predict(x_train)
    Train_predictions = np.argmax(Train_predictions, axis=1)

# Make predictions on test data
test_predictions = model.predict(x_test)
test_predictions = np.argmax(test_predictions, axis=1)

# Convert y_val and y_test from one-hot encoder to their original form
y_val_original = np.argmax(y_val, axis=1)
y_test_original = np.argmax(y_test, axis=1)
if Train_data_test:
    y_train_original = np.argmax(y_train, axis=1)

# Calculate accuracy on validation data
val_accuracy = accuracy_score(y_val_original, val_predictions)

# Calculate accuracy on Train data
if Train_data_test:
    Train_accuracy = accuracy_score(y_val_original, Train_predictions)

# Calculate accuracy on test data
test_accuracy = accuracy_score(y_test_original, test_predictions)

# Print acc
if Train_data_test:
    print(f'The accuracy of the model on Train data is {Train_accuracy:.2%}')
print(f'The accuracy of the model on validation data is {val_accuracy:.2%}')
print(f'The accuracy of the model on test data is {test_accuracy:.2%}')

# Visualize the predictions on validation data as a grid of squares
plt.figure(figsize=(12, 6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    plt.imshow(x_val[i])
    plt.title(f'True: {y_val_original[i]}\nPredicted: {val_predictions[i]}')
    plt.axis('off')
plt.tight_layout()
plt.show()
#Heatmap
plt.figure(figsize=(12, 6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    img = x_val[i]
    heatmap = make_gradcam_heatmap(img[np.newaxis, ...], model, 'top_conv', sensitivity_map = 0.95) 
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    # Apply Adaptive Histogram Equalization
    clahe = cv2.createCLAHE(clipLimit=1, tileGridSize=(4,4))  # Create CLAHE object
    heatmap = clahe.apply(heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    superimposed_img = heatmap * 0.0019 + img
    #clip
    superimposed_img = np.clip(superimposed_img, 0, 1)  # ensure the values are in the range [0, 1]
    plt.imshow(superimposed_img)
    plt.title(f'True: {y_val_original[i]}\nPredicted: {val_predictions[i]}')
    plt.axis('off')
plt.tight_layout()
plt.show()

# Define the list of labels
labels = ['NORMAL', 'PNEUMONIA']

# Create a confusion matrix for validation data
val_cm = confusion_matrix(y_val_original, val_predictions)

# Create a confusion matrix for test data
test_cm = confusion_matrix(y_test_original, test_predictions)

# Plot the confusion matrix as a heatmap for validation data
plt.figure(figsize=(8, 6))
sns.heatmap(val_cm, annot=True, cmap='Blues', fmt='d', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix - Validation Data')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Plot the confusion matrix as a heatmap for test data
plt.figure(figsize=(8, 6))
sns.heatmap(test_cm, annot=True, cmap='Blues', fmt='d', xticklabels=labels, yticklabels=labels)
plt.title('Confusion Matrix - Test Data')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# Define the range of test data sizes to use
data_sizes = range(1, len(x_test), 4)  
# Calculate the probability of a wrong prediction based on test accuracy
prob_wrong = 1 - test_accuracy

# Create a list to store the number of incorrect predictions for each test data size
incorrect_predictions = []

# Generate predictions and track incorrect predictions for each data size
for size in tqdm(data_sizes, desc='Predicting', unit='dpb'):
    # Randomly select a subset of test data
    indices = np.random.choice(len(x_test), size, replace=False)
    x_test_subset = x_test[indices]
    y_test_subset = y_test[indices]

    # Make predictions on the subset of test data
    test_predictions = model.predict(x_test_subset, batch_size=1, verbose=0, max_queue_size=120, workers=1, use_multiprocessing=False)
    test_predictions = np.argmax(test_predictions, axis=1)
    y_test_original_subset = np.argmax(y_test_subset, axis=1)

    # Calculate the number of incorrect predictions
    incorrect_preds = np.sum(test_predictions != y_test_original_subset)
    incorrect_predictions.append(incorrect_preds)
    
# Plot the number of incorrect predictions vs. the number of data points
plt.figure(figsize=(10, 6))
plt.plot(data_sizes, incorrect_predictions)
plt.xlabel('Number of Data Points')
plt.ylabel('Number of Incorrect Predictions')
# Add gridlines for the x and y axes
plt.grid(True)

# Change the tick spacing for the x and y axes
plt.xticks(np.arange(min(data_sizes), max(data_sizes)+1, 50))
plt.yticks(np.arange(0, max(incorrect_predictions) + 5, 3))

plt.title('Number of Incorrect Predictions vs. Number of Data Points')
plt.show()

# Define the range of test data sizes to use
data_sizes = range(1, len(x_test), 1) 

# Calculate the probability of a wrong prediction based on test accuracy
prob_wrong = 1 - test_accuracy

# Create a list to store the probability of getting at least one wrong answer for each test data size
probabilities = []

# Calculate the probability of getting at least one wrong answer for each data size
for size in data_sizes:
    # Calculate the cumulative distribution function (CDF) of the binomial distribution at 0
    cdf = binom.cdf(0, size, prob_wrong)
    # Subtract the CDF from 1 to get the probability of getting at least one wrong answer
    prob = 1 - cdf
    probabilities.append(prob)

# Find the index of the first data point that has a probability greater than prob_L%
index = next((i for i, p in enumerate(probabilities) if p > prob_L), len(probabilities))

# Limit the x-axis to the first data point that has a probability greater than prob_L%
data_sizes = data_sizes[:index+1]
probabilities = probabilities[:index+1]

# Plot the probability vs. the number of data points
plt.figure(figsize=(10, 6))
plt.plot(data_sizes, probabilities)
plt.xlabel('Number of Data Points')
plt.ylabel('Probability')

# Add gridlines for the x and y axes
plt.grid(True)

# Change the tick spacing for the x and y axes
plt.xticks(np.arange(min(data_sizes), max(data_sizes)+1, tick_spacing + 2))
plt.yticks(np.arange(0, max(probabilities)+0.1, tick_spacing / 100))

plt.ylim(top=1.01)

plt.title('Probability of Getting at Least One Wrong Answer vs. Number of Data Points')
plt.show()
# Out:
# 1/1 [==============================] - 2s 2s/step
# 20/20 [==============================] - 2s 93ms/step
# The accuracy of the model on validation data is 81.25%
# The accuracy of the model on test data is 90.87%
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
# Predicting:  24%|██▎       | 37/156 [00:44<02:22,  1.20s/dpb]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\aydin\Desktop\Pneumonia AI\Model_TT.ipynb Cell 43 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/aydin/Desktop/Pneumonia%20AI/Model_TT.ipynb#X55sZmlsZQ%3D%3D?line=129'>130</a> y_test_subset = y_test[indices]
#     <a href='vscode-notebook-cell:/c%3A/Users/aydin/Desktop/Pneumonia%20AI/Model_TT.ipynb#X55sZmlsZQ%3D%3D?line=131'>132</a> # Make predictions on the subset of test data
# --> <a href='vscode-notebook-cell:/c%3A/Users/aydin/Desktop/Pneumonia%20AI/Model_TT.ipynb#X55sZmlsZQ%3D%3D?line=132'>133</a> test_predictions = model.predict(x_test_subset, batch_size=1, verbose=0, max_queue_size=120, workers=1, use_multiprocessing=False)
#     <a href='vscode-notebook-cell:/c%3A/Users/aydin/Desktop/Pneumonia%20AI/Model_TT.ipynb#X55sZmlsZQ%3D%3D?line=133'>134</a> test_predictions = np.argmax(test_predictions, axis=1)
#     <a href='vscode-notebook-cell:/c%3A/Users/aydin/Desktop/Pneumonia%20AI/Model_TT.ipynb#X55sZmlsZQ%3D%3D?line=134'>135</a> y_test_original_subset = np.argmax(y_test_subset, axis=1)
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\engine\training.py:2253, in Model.predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2251 for step in data_handler.steps():
#    2252     callbacks.on_predict_batch_begin(step)
# -> 2253     tmp_batch_outputs = self.predict_function(iterator)
#    2254     if data_handler.should_sync:
#    2255         context.async_wait()
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\def_function.py:954, in Function._call(self, *args, **kwds)
#     951 self._lock.release()
#     952 # In this case we have not created variables on the first call. So we can
#     953 # run the first trace but we should fail if variables are created.
# --> 954 results = self._stateful_fn(*args, **kwds)
#     955 if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     956   raise ValueError("Creating variables on a non-first call to a function"
#     957                    " decorated with tf.function.")
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File c:\Users\aydin\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:
